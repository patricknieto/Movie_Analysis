# %% [markdown]
# # Challenge Set #2
#
# Topic:        Exploring and visualizing our scraped movie data in pandas
#
# Date:         4/25/2016
#
# Name:         Patrick Nieto

# %%
import urllib 
from bs4 import BeautifulSoup  
import logging  
logging.basicConfig(level=logging.DEBUG)
import string
string.ascii_uppercase
from urllib.request import urlopen
import requests
import re
import pandas as pd
import pickle
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
with open('../Data_gathering/MovieDict.pickle', 'rb') as handle:
  b = pickle.load(handle)

# %%
df1 = pd.DataFrame(b)

# %%
df1.head()
# Out:
#                                               actors  \
# 0  {'Anthony Hopkins': ([-140 days, 0:00:00], '0'...
# 1  {'Tom Hanks': ([-672 days, 0:00:00], '0', 1956...
# 2  {'Anthony Hopkins': ([-140 days, 0:00:00], '0'...
# 3  {'Joaquin Phoenix': ([-217 days, 0:00:00], '0'...
# 4  {'Mel Gibson': ([-308 days, 0:00:00], '0', 195...
#
#                                            directors  domestic_total_gross  \
# 0  {'Ron Howard': ([-812 days, 0:00:00], '0', 195...             260044825
# 1  {'Robert Zemeckis': ([-1062 days, 0:00:00], No...             233632142
# 2  {'John Woo': ([-2155 days, 0:00:00], None, 194...             215409889
# 3  {'Ridley Scott': ([-294 days, 0:00:00], None, ...             187705427
# 4  {'Nancy Meyers': ([-2100 days, 0:00:00], None,...             182811707
#
#    production rating release_date  runtime                           title  \
# 0   123000000     PG   2000-11-17      104  How the Grinch Stole Christmas
# ...

# %%
data1 = pd.DataFrame()
for i in range(0, len(df1['directors'])):
    directors = pd.DataFrame(df1['directors'][i])
    directors=directors.T
    directors['title']=df1['title'][i]
    directors['Domestic'] = df1['domestic_total_gross'][i]
    directors['production'] = df1['production'][i]
    directors['runtime'] = df1['runtime'][i]
    directors['rating'] = df1['rating'][i]
    directors['release_date'] = df1['release_date'][i]
    data1 = data1.append(directors)
data1 = data1.reset_index()
data1.rename(columns={'index': 'director', 0: 'days passed directors', 1: 'director_gender', 2: 'director_bday'}, inplace=True)
data1['days passed directors'] = data1['days passed directors'].apply(lambda x: abs(x[0]) if isinstance(x, list) else None)
data1['release_date'] = data1['release_date']#.apply(lambda x: pd.to_datetime(x))
data1['director_bday'] = data1['director_bday'].apply(lambda x: pd.to_datetime(x))
data1['director_age'] = abs(data1['director_bday'] - data1['release_date'])
data1 = data1.drop('director_gender', 1)

# %%
data1['ROI'] = (data1['Domestic']- data1.production)/data1['production']

# %%
data1['days passed directors'] = data1['days passed directors'].apply(lambda day: abs((np.timedelta64(day) / np.timedelta64(1, 'D')) - 1).astype(int) if day else None)
data1['director_age'] = data1['director_age'].apply(lambda age: abs(((np.timedelta64(age) / np.timedelta64(1, 'D')) - 1)/365).astype(int) if age else None)

# %%
data1.head()
# Out:
#           director  days passed directors director_bday  \
# 0       Ron Howard                    811    1954-03-01
# 1  Robert Zemeckis                   1061    1952-05-14
# 2         John Woo                   2154    1946-05-01
# 3     Ridley Scott                    293    1937-11-30
# 4     Nancy Meyers                   2099    1949-12-08
#
#                             title   Domestic  production  runtime rating  \
# 0  How the Grinch Stole Christmas  260044825   123000000      104     PG
# 1                       Cast Away  233632142    90000000      143  PG-13
# 2          Mission: Impossible II  215409889   125000000      123  PG-13
# 3                       Gladiator  187705427   103000000      155      R
# 4                 What Women Want  182811707    70000000      127  PG-13
#
#   release_date  director_age       ROI
# 0   2000-11-17            46  1.114186
# 1   2000-12-22            48  1.595913
# 2   2000-05-24            54  0.723279
# ...

# %%
final = data1[[3,8,6,7,4,5,10,0,9,2,1]].dropna()

# %%
data1['release_date'] = data1['release_date'].apply(lambda x: pd.to_datetime(x))

# %%
final.release_date[0]
# Out:
# Timestamp('2000-11-17 00:00:00')

# %%
final.release_date = pd.to_datetime(final.release_date, format='%Y%m%d')

# %%
final.release_date.min()
# Out:
# Timestamp('2000-01-14 00:00:00')

# %%
final.head()
# Out:
#                             title release_date  runtime rating   Domestic  \
# 0  How the Grinch Stole Christmas   2000-11-17      104     PG  260044825
# 1                       Cast Away   2000-12-22      143  PG-13  233632142
# 2          Mission: Impossible II   2000-05-24      123  PG-13  215409889
# 3                       Gladiator   2000-05-05      155      R  187705427
# 4                 What Women Want   2000-12-15      127  PG-13  182811707
#
#    production       ROI         director  director_age director_bday  \
# 0   123000000  1.114186       Ron Howard            46    1954-03-01
# 1    90000000  1.595913  Robert Zemeckis            48    1952-05-14
# 2   125000000  0.723279         John Woo            54    1946-05-01
# 3   103000000  0.822383     Ridley Scott            62    1937-11-30
# 4    70000000  1.611596     Nancy Meyers            51    1949-12-08
#
#    days passed directors
# 0                    811
# 1                   1061
# 2                   2154
# ...

# %% [markdown]
# ### Challenge 1
#
# Plot domestic total gross over time.

# %%
# %matplotlib inline

# %%
ch1 = final[[1,4]].sort_values(by='release_date')
plt.figure(figsize=(20,10))
plt.plot(ch1.release_date, ch1.Domestic)

# %% [markdown]
# ## Challenge 2
# Plot runtime vs. domestic total gross.

# %%
ch2 = final[[2,4]]
g = sns.lmplot('runtime', 'Domestic', data = ch2, size = 8)

# %% [markdown]
# ## Challenge 3
# Group your data by Rating and find the average runtime and domestic total gross at each level of Rating.

# %%
grouped = final.groupby('rating').mean()
grouped.head()
# Out:
#            runtime      Domestic       production       ROI  director_age  \
# rating
# G       104.000000  1.356582e+08  82615384.615385  1.467573     50.307692
# NC-17   133.500000  4.908412e+06  10000000.000000 -0.325316     53.500000
# PG      102.241935  9.932577e+07  73883870.967742  0.732867     43.612903
# PG-13   114.366102  9.776581e+07  70920677.966102  0.654795     46.227119
# R       114.541818  4.762953e+07  38363272.727273  1.271992     46.730909
#
#         days passed directors
# rating
# G                1.412308e+03
# NC-17            9.020000e+02
# PG               1.033629e+03
# PG-13           -6.253134e+16
# R               -3.353953e+16

# %% [markdown]
# ## Challenge 4
#
# Make one figure with (N=the number of MPAA ratings there are) subplots, and in each plot the release date vs the domestic total gross.

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize = (16,11))
plt.figure(figsize=(20,10))

G= final[final.rating == 'G'].sort_values(by = 'release_date')
PG= final[final.rating == 'PG'].sort_values(by = 'release_date')
PG13= final[final.rating == 'PG-13'].sort_values(by = 'release_date')
R= final[final.rating == 'R'].sort_values(by = 'release_date')
NC= final[final.rating == 'NC-17'].sort_values(by = 'release_date')

G.plot(y = 'Domestic', x = 'release_date',ax=axes[0,0], legend = False, title = 'Domestic Gross for G Rates Movies')
PG.plot(y = 'Domestic', x = 'release_date',ax=axes[0,1], legend = False, title = 'Domestic Gross for PG Rates Movies')
PG13.plot(y = 'Domestic', x = 'release_date',ax=axes[0,2], legend = False, title = 'Domestic Gross for PG-13 Rates Movies')
R.plot(y = 'Domestic', x = 'release_date',ax=axes[1,0], legend = False, title = 'Domestic Gross for R Rates Movies')
NC.plot(y = 'Domestic', x = 'release_date', ax=axes[1,1], legend = False, title = 'Domestic Gross for NC-17 Rates Movies')

# %% [markdown]
# ## Challenge 5
# What director in your dataset has the highest gross per movie?

# %%
grouped = final.groupby('director').mean().sort_values(by = 'Domestic', ascending = False)
grouped.head(5)
# Out:
#                runtime     Domestic  production       ROI  director_age  \
# director
# George Lucas    139.00  341230914.5   114000000  1.996488          59.5
# Sam Raimi       121.75  288980782.0   156750000  0.870007          45.5
# Peter Jackson   175.80  258475115.4   110600000  1.545486          43.0
# John Lasseter   116.00  244082982.0   120000000  1.034025          49.0
# Brad Bird       113.00  233943373.0   121000000  1.109028          48.0
#
#                days passed directors
# director
# George Lucas                    1098
# Sam Raimi                       1378
# Peter Jackson                    368
# John Lasseter                   1840
# Brad Bird                       1252

# %% [markdown]
# ## Challenge 6
#
# Bin your dataset into months and make a bar graph of the mean domestic total gross by month. Error bars will represent the standard error of the mean.
#
# Title of graph should include: Mean Domestic Total Gross by Month in 2013
#
# Topic for consideration: what is the correct formula for the standard error of the mean? Examine the error bars and see if they are "reasonable."

# %%
final.release_date = final.release_date.apply(lambda x: x.month)
grouped = final.groupby('release_date', as_index=False).mean().sort_values("Domestic", ascending=False)
grouped
# Out:
#     release_date     runtime      Domestic    production       ROI  \
# 4              5  121.477273  1.549392e+08  1.082386e+08  0.689976
# 6              7  108.807692  1.162861e+08  7.702885e+07  1.118156
# 5              6  113.397059  1.108273e+08  8.077500e+07  1.003924
# 11            12  125.010204  8.637480e+07  6.028878e+07  0.829926
# 10            11  116.237288  8.260187e+07  6.763220e+07  1.059233
# 7              8  106.983051  7.147678e+07  4.831356e+07  0.865296
# 1              2  105.129032  6.475602e+07  5.083871e+07  1.033918
# 2              3  112.315789  5.736439e+07  4.619649e+07  0.416831
# 0              1  100.904762  4.380823e+07  2.250476e+07  1.544018
# 9             10  110.485294  4.098133e+07  3.218676e+07  1.957483
# 3              4  106.380952  3.654405e+07  4.025000e+07  0.079056
# 8              9  110.395833  2.908379e+07  3.282292e+07  0.635701
#
#     director_age  days passed directors
# 4      45.545455           1.054295e+03
# ...

# %%
f, ax = plt.subplots(figsize=(15, 6))
sns.set_color_codes("pastel")
sns.barplot(x="release_date", y="Domestic", data=grouped,
            label="Total Domestic by Month", color="b")
ax.set(title = "Mean Domestic Total Gross by Month (2000 - 2009)", xlabel="Month")
