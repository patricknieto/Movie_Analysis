# %%
import urllib 
from bs4 import BeautifulSoup  
import logging  
from urllib.request import urlopen
import requests
import re
import pandas as pd

# %%
def get_pages ():
    big_url_list = []
    for i in range(0,10):
        url = 'http://www.boxofficemojo.com/yearly/chart/?yr=200' + str(i) + '&p=.htm'
        big_url_list.append(url)
    for i in range(10, 16):
        url = 'http://www.boxofficemojo.com/yearly/chart/?yr=20' + str(i) + '&p=.htm'
        big_url_list.append(url)
    return big_url_list

# %%
def get_soup(url):
    #for url in url_list:
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page, 'lxml')
    return soup

# %%
def generate_links(soup):
    my_list = []
    for link in soup.find("body").find_all('a', href=True):
        if link['href'].startswith('/movies/?id='):
            my_list.append('http://www.boxofficemojo.com' + link['href'])
        elif link['href'] == '' or link['href'].startswith('#'):
            continue
    link_list = (my_list[1:])
    return(link_list)

# %%
def movie_links(links, url_set):
    for link in links:
        url = 'http://www.boxofficemojo.com' + str(link)
        url_set.append(url)
    return url_set

# %%
def get_title(pages):
    titleList = []
    for url in pages:
        title_string = get_soup(url).find('title').text
        title = title_string.split('(')[0].strip()
        titleList.append(title)
    return titleList

# %%
# Out:
# ['http://www.boxofficemojo.com/movies/?id=grinch.htm',
#  'http://www.boxofficemojo.com/movies/?id=castaway.htm',
#  'http://www.boxofficemojo.com/movies/?id=mi2.htm',
#  'http://www.boxofficemojo.com/movies/?id=gladiator.htm',
#  'http://www.boxofficemojo.com/movies/?id=whatwomenwant.htm']

# %%
import dateutil.parser

def to_date(datestring):
    date = dateutil.parser.parse(datestring)
    return date

def money_to_int(moneystring):
    moneystring = moneystring.replace('$', '').replace(',', '')
    return int(moneystring)

def runtime_to_minutes(runtimestring):
    runtime = runtimestring.split()
    try:
        minutes = int(runtime[0])*60 + int(runtime[2])
        return minutes
    except:
        return None

# %%
soup = get_soup('http://www.boxofficemojo.com/movies/?id=jurassicpark4.htm')
my_list = []
for link in soup.find("body").find_all('a', href=True):
        if link['href'].startswith('/people/chart/?view=Director&id='):
            print(link.text)
# Out:
# Colin Trevorrow

# %%
from collections import defaultdict
def get_movie_values(pages, field_names):
    temp = []
    tempdict = defaultdict(list)
    count = 0
    '''Grab a value from boxofficemojo HTML
    
    Takes a string attribute of a movie on the page and returns the string in the next sibling object
    (the value for that attribute)or None if nothing is found. '''
    for url in pages:
        soup = get_soup(url)
        
        for name in field_names:
            obj = soup.find(text=re.compile(name))
            
            if not obj: 
                return None
            next_sibling = obj.findNextSibling()
            if next_sibling:
                tempdict[name].append(next_sibling.text)
            else:
                tempdict[name].append('0')   

    return tempdict

# %%
a = soup.find(class = "mp_box_content"):

# %%
def get_director_value(pages, name)
    for url in pages:
        for link in soup.find("body").find_all('a', href=True):
            try:
                if link['href'].startswith('/people/chart/?view=Director&id='):
                tempdict['Director'].append(link.text)
            except:
                return None
# Out:
#   File "<ipython-input-403-b45cce3ea044>", line 4
#     tempdict['Director'].append(link.text)
#            ^
# IndentationError: expected an indented block

# %%
            
for link in soup.find("body").find_all('a', href=True):
    if link['href'].startswith('/people/chart/?view=Director&id='):
            print(count)
            tempdict['Director'].append(link.text)
    else:
# Out:
#   File "<ipython-input-382-b0cbee4385d8>", line 4
#     print(count)
#                 ^
# IndentationError: expected an indented block

# %%
def data_series(rawInfo, title, obs):
    DomesticList = []
    ReleaseList = []
    RuntimeList = []
    RatingList = []
    DirectorList = []

    for raw in rawInfo['Domestic Total']:
        DomesticList.append(money_to_int(raw))
    
    for raw in rawInfo['Release Date']:
         ReleaseList.append(to_date(raw))
        
    for raw in rawInfo['Runtime']:
        RuntimeList.append(runtime_to_minutes(raw))
        
    for raw in rawInfo['MPAA Rating']:
        RatingList.append(raw)
    
    for raw in rawInfo['Director']:
        DirectorList.append(raw)
    
    d = {'title' : pd.Series(title, index=range(1,obs)),
         'Domestic Total Gross' : pd.Series(DomesticList, index = range(1,obs)),
         'Release Date' : pd.Series(ReleaseList, index = range(1,obs)),
         'Runtime' : pd.Series(RuntimeList, index = range(1,obs)),
         'Rating' : pd.Series(RatingList, index = range(1,obs)),
         'Rank' : pd.Series(range(1,1601), index = range(1,obs))}
         #'Director' : pd.Series(DirectorList, index = range(1,101))}
    return d

# %% [markdown]
# # * Run Program *

# %%
field_names = ['Release Date', 'Domestic Total', 'Runtime', 'MPAA Rating']

# %%
pages = []

for url in get_pages():
    soup_result = get_soup(url)
    for links in generate_links(soup_result):
        pages.append(links)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="en">
# <HEAD>
# <TITLE>2000 Yearly Box Office Results - Box Office Mojo</TITLE>
# <META NAME="keywords" CONTENT="2000, year, yearly, box, office, result, list, movie, movies, listing, listings, top movies, all time, film">
# <META NAME="description" CONTENT="Yearly box office results for 2000.">
# <link rel="stylesheet" href="/css/mojo.css?1" type="text/css" media="screen" title="no title" charset="utf-8">
# <link rel="stylesheet" href="/css/mojo.css?1" type="text/css" media="print" title="no title" charset="utf-8"></head>
# <body>
# 	<iframe id="sis_pixel_sitewide" width="1" height="1" frameborder="0" marginwidth="0" marginheight="0" style="display: none;"></iframe>
# <script>
#     setTimeout(function(){
#         try{
#             //sis3.0 pixel
#             var cacheBust = Math.random() * 10000000000000000,
#                 url_sis3 = 'http://s.amazon-adsystem.com/iu3?',
#                 params_sis3 = [
#                     "d=boxofficemojo.com",
#                     "cb=" + cacheBust
#                 ];
#
#             (document.getElementById('sis_pixel_sitewide')).src = url_sis3 + params_sis3.join('&');
#         }catch(e){
#             if (window.ueLogError) {
#                 window.ueLogError(e);
#             }
#         }
#     }, 5);
# </script>
#
# <div id="container">
# <div>
# <script type="text/javascript">
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#
#     (function() {
#         var gads = document.createElement("script");
#         gads.async = true;
#         gads.type = "text/javascript";
#
#         var useSSL = "https:" == document.location.protocol;
#         gads.src = (useSSL ? "https:" : "http:") + "//www.googletagservices.com/tag/js/gpt.js";
#
#         var node = document.getElementsByTagName("script")[0];
#         node.parentNode.insertBefore(gads, node);
#     })();
# </script>
#
# <script type="text/javascript">
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-2831726-1']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     (document.getElementsByTagName('head')[0] || document.getElementsByTagName('body')[0]).appendChild(ga);
#   })();
#
# </script>
#
# 	<div id="hp_banner">
# 	<div id="top_links">
# 		<div style="float: left"><a href="/daily/chart/">Daily Box Office (Wed.)</a> | <a href="/weekend/chart/">Weekend Box Office (Apr. 8&ndash;10)</a> | <a href="/movies/?id=michelledarnell.htm">#1 Movie: 'The Boss'</a> | <a href="http://www.imdb.com/showtimes/?ref_=mojo">Showtimes</a></div>
# 		<div style="float: right">Updated 4/14/2016 10:41 P.M. Pacific Time</div>
# 		<div style="clear:both; height: 0px"></div>
# 	</div>
# </div>
#
# <div id="header">
# 	<div id="leaderboard"><script type="text/javascript">
#     googletag.cmd.push(function() {
#         googletag.defineSlot("/4215/imdb2.bom.other", [[728, 90]], "ad-slot-1").addService(googletag.pubads().setTargeting("p", "t"));
#         googletag.pubads().enableSingleRequest();
#         googletag.enableServices();
#     });
#     googletag.cmd.push(function() { googletag.display("ad-slot-1"); });
# </script></div>	<div id="hp_logo"><a href="/"><img src="/img/misc/bom_logo1.png" width="245" height="56" alt="Box Office Mojo"></a></div>
# 	<div style="clear:both; height: 0px"></div>
# </div>
#
#
# </div>
#
#
# <div id="main">
# <!-- COLUMN 1 of 4 -->
# 	<div id="leftnav">
# <!-- google_ad_section_start(weight=ignore) -->
# <!-- <table id="navleft" cellspacing="0" cellpadding="2" border="0"> -->
# <ul id="leftnav">
# <li class="nl_section">Search Site</li>
# <li class="nl_link" style="padding-left:0px">
# 	<form name="searchbox" method="POST" action="/search/q.php">
# 	<input name="q"  type="text" style="font-size: 9 pt; font-weight: bold; width: 90px;"><br>
# 	<input type="submit" value="Search..." ></form>
# </li>
# <li class='nl_section'>Social</li>
# <li class="nl_link"><a href="http://facebook.com/boxofficemojo" style="vertical-align:middle;"><img src="/images/FaceBook_16x16.png" border="0" alt="Facebook Logo">Facebook</a></li>
# <li class="nl_link"><a href="http://twitter.com/boxofficemojo" style="vertical-align:middle;"><img src="/images/Twitter_16x16.png" border="0" alt="Twitter Logo">Twitter</a></li>
#
# <li class='nl_section'>Features</li>
# <li class='nl_link'><a href="/news/">News</a></li>
# <li class='nl_link'><a href="/schedule/">Release Sched.</a></li>
# <li class='nl_link'><a href="http://www.imdb.com/showtimes?ref_=mojo">Showtimes<br/><span style="margin-left:7px;color: #999999; font-size: 9px;">at <img src="/images/mojo_imdb_sm.png"/></span></a></li>
# <li class='nl_section'>Box Office</li>
# <li class='nl_link'><a href="/daily/">Daily</a></li>
# <li class='nl_link'><a href="/weekend/">Weekend</a></li>
# <li class='nl_link'><a href="/weekly/">Weekly</a></li>
# <li class='nl_link'><a href="/monthly/">Monthly</a></li>
# <li class='nl_link'><a href="/quarterly/">Quarterly</a></li>
# <li class='nl_link'><a href="/seasonal/">Seasonal</a></li>
# <li class='nl_link_current'><a href="/yearly/">Yearly</a></li>
# <li class='nl_link'><a href="/alltime/">All Time</a></li>
# <li class='nl_link'><a href="/chartwatch/">Chart Watch</a></li>
# <li class='nl_link'><a href="/intl/">International</a></li>
# <li class='nl_section'>Indices</li>
# <li class='nl_link'><a href="/movies/">Movies A-Z</a></li>
# <li class='nl_link'><a href="/studio/">Studios</a></li>
# <li class='nl_link'><a href="/people/">People</a></li>
# <li class='nl_link'><a href="/genres/">Genres</a></li>
# <li class='nl_link'><a href="/franchises/">Franchises</a></li>
# <li class='nl_link'><a href="/showdowns/">Showdowns</a></li>
# <li class='nl_link'><a href="/oscar/">Oscar</a></li>
# <li class='nl_link'><a href="/counts/">Theater Counts</a></li>
# </ul>
# </div>
# 	<div id="body">
# 	<div id="addthis"><table border="0" cellspacing="0" cellpadding="0">
# <tr>
# <form method="POST" action="/adjuster.php" name="adjuster">
# <input type="hidden" name="returnURL" value="/yearly/chart/?yr=2000&amp;p=.htm">
# <td valign="center">
#   <font face="Verdana" size="2"><a href="/about/adjuster.htm"><b>Adjuster:</b></a></font>
#   <select size="1" name="ticketyr" style="font-family: Verdana; font-size: 10pt">
#   <option value="0" selected>Actuals</option>
#   <option value="1" >Est. Tckts</option>
# <script language="javascript">
#   for(i=2016; i>=1933; i--) {
#   	document.write('<option value="' + i + '"');
# 	if(i=='0') document.write(' selected');
# 	document.write('>' + i );
# 	if(i=='0') document.write(', $' + '0.00');
# 	document.write('</option>');
#   }
# </script>
#   <option value="1929" >1929</option>
#   <option value="1924" >1924</option>
#   <option value="1910" >1910</option>
#   </select><input type="submit" name="Go" value="Go" style="font-size: 10pt; height: 22">
#
# </td></form></tr></table>
#
# </div>
# 	<h2><a href="/yearly/">Yearly Box Office</a></h2>
#
# 	<table border="0" cellpadding="0" cellspacing="0" width="100%">
# 		<tr><td bgcolor="#8b0000" colspan="2"><img src="/images/space.gif" border="0" width="1" height="5"></td></tr>
# 	</table>
#
# <table border="0" width="100%" cellspacing="0" cellpadding="3">
# 	<tr>
# 		<td bgcolor="#FFFFFF" align="center"><b><font face="Verdana" size="1"><a href="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&p=.htm">ALL RELEASES</a></font></b></td>
# 		<td bgcolor="#DCDCDC" align="center"><b><font face="Verdana" size="1"><a href="/yearly/chart/?view=widedate&view2=domestic&yr=2000&p=.htm">WIDE RELEASES</font></b></td>
# 		<td bgcolor="#DCDCDC" align="center"><b><font face="Verdana" size="1"><a href="/yearly/chart/?view=limited&view2=domestic&yr=2000&p=.htm">LIMITED RELEASES</font></b></td>
# 				<td bgcolor="#DCDCDC" align="center"><b><font face="Verdana" size="1"><a href="/yearly/chart/?view=calendargross&view2=domestic&yr=2000&p=.htm">CALENDAR GROSSES</font></b></td>
# 			</tr>
# </table>
# <table border="0" cellspacing="0" cellpadding="0" width="100%"><tr><td valign="top" align="center"><br>
# <h1>2000 DOMESTIC GROSSES</h1><p>Total Grosses of all Movies Released in 2000</h1></b></FONT></p>
#
# <center><font face="Verdana" size="4"><b><font face="Verdana" size="5">#1&#150;100</font> - <a href="/yearly/chart/?page=2&view=releasedate&view2=domestic&yr=2000&p=.htm">#101&#150;200</a> - <a href="/yearly/chart/?page=3&view=releasedate&view2=domestic&yr=2000&p=.htm">#201&#150;300</a> - <a href="/yearly/chart/?page=4&view=releasedate&view2=domestic&yr=2000&p=.htm">#301&#150;374</a></b></font></center><table border="0" cellspacing="0" cellpadding="0"><tr><td valign="bottom"><font face="Verdana" size="1"><b><a href="/yearly/chart/?yr=1999&view=releasedate&view2=domestic&sort=gross&order=DESC&&p=.htm">&lt; Previous Year</a></b></font></td><td align="center"><table border="0" cellspacing="0" cellpadding="0">
# 					<form method="POST" action="yearly.asof.php" name="asofjump">
# 					<tr><td><font face="Verdana" size="1"><br>Data as of:
# 					<select size="1" name="asof" style="font-size: 8pt">
# 					<option selected value="today">Today</option>
# 					<option  value="sametime">Today in 2000</option>
# 					<option value="2000-01-31">Jan. 31, 2000</option>
# 					<option value="2000-02-29">Feb. 29, 2000</option>
# 					<option value="2000-03-31">Mar. 31, 2000</option>
# 					<option value="2000-04-30">Apr. 30, 2000</option>
# 					<option value="2000-05-31">May 31, 2000</option>
# 					<option value="2000-06-30">Jun. 30, 2000</option>
# 					<option value="2000-07-31">Jul. 31, 2000</option>
# 					<option value="2000-08-31">Aug. 31, 2000</option>
# 					<option value="2000-09-30">Sep. 30, 2000</option>
# 					<option value="2000-10-31">Oct. 31, 2000</option>
# 					<option value="2000-11-30">Nov. 30, 2000</option>
# 					<option value="2000-12-31">Dec. 31, 2000</option>
# 					<option value="specify">Specify Date</option>
# 					<option value="about">About this feature</option>
# 					</select> or (<select size="1" name="asof_mo" style="font-size: 8pt">
# 					<option selected value="">Month</option>
#
# 					<option value="01">Jan.</option>
# 					<option value="02">Feb.</option>
# 					<option value="03">Mar.</option>
# 					<option value="04">Apr.</option>
# 					<option value="05">May</option>
# 					<option value="06">Jun.</option>
# 					<option value="07">Jul.</option>
# 					<option value="08">Aug.</option>
# 					<option value="09">Sep.</option>
# 					<option value="10">Oct.</option>
# 					<option value="11">Nov.</option>
# 					<option value="12">Dec.</option>
# 					</select> / <select size="1" name="asof_day" style="font-size: 8pt">
# 					<option selected value="">Day</option>
# 					<option value="01">1</option>
# 					<option value="02">2</option>
# 					<option value="03">3</option>
# 					<option value="04">4</option>
# 					<option value="05">5</option>
# 					<option value="06">6</option>
# 					<option value="07">7</option>
# 					<option value="08">8</option>
# 					<option value="09">9</option>
# 					<option value="10">10</option>
# 					<option value="11">11</option>
# 					<option value="12">12</option>
# 					<option value="13">13</option>
# 					<option value="14">14</option>
# 					<option value="15">15</option>
# 					<option value="16">16</option>
# 					<option value="17">17</option>
# 					<option value="18">18</option>
# 					<option value="19">19</option>
# 					<option value="20">20</option>
# 					<option value="21">21</option>
# 					<option value="22">22</option>
# 					<option value="23">23</option>
# 					<option value="24">24</option>
# 					<option value="25">25</option>
# 					<option value="26">26</option>
# 					<option value="27">27</option>
# 					<option value="28">28</option>
# 					<option value="29">29</option>
# 					<option value="30">30</option>
# 					<option value="31">31</option>
# 					</select> / <select size="1" name="asof_yr" style="font-size: 8pt">
# 						<option selected>2000</option>
# 						<option>2001</option>
# 						</select>) <input type="submit" value="Go" name="go" style="font-size: 8pt; height: 16">
# 					</font></td></tr>
# 					<input type="hidden" name="jumpstuff" value="view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&p=.htm">
# 					<input type="hidden" name="curasof" value="today">
# 					<input type="hidden" name="yr" value="2000">
# 					</form>
# 					</table>
# 				</font></td><td valign="bottom" align="right"><font face="Verdana" size="1"><b><a href="/yearly/chart/?yr=2001&view=releasedate&view2=domestic&sort=gross&order=DESC&&p=.htm">Next Year &gt;</a></b></font></td></tr><tr><td colspan="3"><table border="0" cellspacing="1" cellpadding="5" bgcolor="#ffffff"><tr bgcolor="#dcdcdc"><td align="center"><font size="2"><a href="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=ASC&p=.htm"><b>Rank</b></a></font></td><td align="center"><font size="2"><a href="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=title&order=ASC&p=.htm">Movie Title (click to view)</a></font></td><td align="center"><font size="2"><a href="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=studio&order=ASC&p=.htm">Studio</a><br><script language="javascript">
# function MojoDrop1() {
# var number = document.MojoDropDown1.mojolinks1.selectedIndex;location.href = document.MojoDropDown1.mojolinks1.options[number].value;}</script>
# <table border="0" cellspacing="0" cellpadding="0">
# <form name="MojoDropDown1"><tr><td>
# <select name="mojolinks1" style="font-family: Verdana; font-size: 8pt" onChange="MojoDrop1(this.form)">
# <option selected>Filter</option><option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=7thart.htm">7Art</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=artisticlicense.htm">AL</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=alliance.htm">All.</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=arrow.htm">Arro.</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=artisan.htm">Art.</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=buenavista.htm">BV</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=canwestfilms.htm">CanW</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=castlehill.htm">Castle</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=cho.htm">Cho</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=cowboy.htm">Cow.</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=destination.htm">Dest.</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=dimension.htm">Dim.</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=dreamworks.htm">DW</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=empirepictures.htm">Emp.</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=equinox.htm">Equin.</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=eros.htm">Eros</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=filmacres.htm">FAc</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=firstlook.htm">First</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=fineline.htm">FL</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=focus.htm">Focus</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=fox.htm">Fox</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=foxsearchlight.htm">FoxS</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=firstrun.htm">FRun</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=heliograph.htm">Hel.</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=hollywoodclassics.htm">HoC</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=hombre.htm">Hom.</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=independentartists.htm">IA</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=idp.htm">IDP</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=ifc.htm">IFC</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=imax.htm">Imax</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=indican.htm">Indic.</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=iron.htm">Iron</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=keystone.htm">Key.</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=kino.htm">Kino</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=newlatin.htm">Latin</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=cinemalibre.htm">Libre</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=lions_gate.htm">Lions</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=lot47.htm">Lot47</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=mgm.htm">MGM</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=miramax.htm">Mira.</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=manga.htm">Mng</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=monarch.htm">Mnr.</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=unknown.htm">N/A</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=newline.htm">NL</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=newyorker.htm">NYer</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=odeon.htm">Ode.</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=palm.htm">Palm</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=paramount.htm">Par.</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=paramountclassics.htm">ParC</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio=palisades.htm">PEC</option>
# <option value="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&studio
# 					<form method="POST" action="yearly.asof.php" name="asofjump">
# 					<tr><td><font face="Verdana" size="1"><br>Data as of:
# 					<select size="1" name="asof" style="font-size: 8pt">
# 					<option selected value="today">Today</option>
# 					<option  value="sametime">Today in 2000</option>
# 					<option value="2000-01-31">Jan. 31, 2000</option>
# 					<option value="2000-02-29">Feb. 29, 2000</option>
# 					<option value="2000-03-31">Mar. 31, 2000</option>
# 					<option value="2000-04-30">Apr. 30, 2000</option>
# 					<option value="2000-05-31">May 31, 2000</option>
# 					<option value="2000-06-30">Jun. 30, 2000</option>
# 					<option value="2000-07-31">Jul. 31, 2000</option>
# 					<option value="2000-08-31">Aug. 31, 2000</option>
# 					<option value="2000-09-30">Sep. 30, 2000</option>
# 					<option value="2000-10-31">Oct. 31, 2000</option>
# 					<option value="2000-11-30">Nov. 30, 2000</option>
# 					<option value="2000-12-31">Dec. 31, 2000</option>
# 					<option value="specify">Specify Date</option>
# 					<option value="about">About this feature</option>
# 					</select> or (<select size="1" name="asof_mo" style="font-size: 8pt">
# 					<option selected value="">Month</option>
#
# 					<option value="01">Jan.</option>
# 					<option value="02">Feb.</option>
# 					<option value="03">Mar.</option>
# 					<option value="04">Apr.</option>
# 					<option value="05">May</option>
# 					<option value="06">Jun.</option>
# 					<option value="07">Jul.</option>
# 					<option value="08">Aug.</option>
# 					<option value="09">Sep.</option>
# 					<option value="10">Oct.</option>
# 					<option value="11">Nov.</option>
# 					<option value="12">Dec.</option>
# 					</select> / <select size="1" name="asof_day" style="font-size: 8pt">
# 					<option selected value="">Day</option>
# 					<option value="01">1</option>
# 					<option value="02">2</option>
# 					<option value="03">3</option>
# 					<option value="04">4</option>
# 					<option value="05">5</option>
# 					<option value="06">6</option>
# 					<option value="07">7</option>
# 					<option value="08">8</option>
# 					<option value="09">9</option>
# 					<option value="10">10</option>
# 					<option value="11">11</option>
# 					<option value="12">12</option>
# 					<option value="13">13</option>
# 					<option value="14">14</option>
# 					<option value="15">15</option>
# 					<option value="16">16</option>
# 					<option value="17">17</option>
# 					<option value="18">18</option>
# 					<option value="19">19</option>
# 					<option value="20">20</option>
# 					<option value="21">21</option>
# 					<option value="22">22</option>
# 					<option value="23">23</option>
# 					<option value="24">24</option>
# 					<option value="25">25</option>
# 					<option value="26">26</option>
# 					<option value="27">27</option>
# 					<option value="28">28</option>
# 					<option value="29">29</option>
# 					<option value="30">30</option>
# 					<option value="31">31</option>
# 					</select> / <select size="1" name="asof_yr" style="font-size: 8pt">
# 						<option selected>2000</option>
# 						<option>2001</option>
# 						</select>) <input type="submit" value="Go" name="go" style="font-size: 8pt; height: 16">
# 					</font></td></tr>
# 					<input type="hidden" name="jumpstuff" value="view=releasedate&view2=domestic&yr=2000&sort=gross&order=DESC&p=.htm">
# 					<input type="hidden" name="curasof" value="today">
# 					<input type="hidden" name="yr" value="2000">
# 					</form>
# 					</table>
# 				</font></td><td valign="bottom" align="right"><font face="Verdana" size="1"><b><a href="/yearly/chart/?yr=2001&view=releasedate&view2=domestic&sort=gross&order=DESC&&p=.htm">Next Year &gt;</a></b></font></td></tr></table><center><font face="Verdana" size="4"><b><font face="Verdana" size="5">#1&#150;100</font> - <a href="/yearly/chart/?page=2&view=releasedate&view2=domestic&yr=2000&p=.htm">#101&#150;200</a> - <a href="/yearly/chart/?page=3&view=releasedate&view2=domestic&yr=2000&p=.htm">#201&#150;300</a> - <a href="/yearly/chart/?page=4&view=releasedate&view2=domestic&yr=2000&p=.htm">#301&#150;374</a></b></font></center><br><font face="Verdana" size="2">Note: <b>RELEASE DATE</b> shows all movies that opened in a given time period and their total grosses. <b>WIDE RELEASES</b> shows only movies released in 600 or more theaters and their total grosses, grouped by wide release date. <b>LIMITED RELEASES</b> shows only movies released in less than 600 theaters and their total grosses, grouped by release date. <b>CALENDAR GROSSES</b> shows all movies playing during the indicated time period, both new and holdover, and their grosses (or estimated grosses) during that time period. Movies released outside the indicated time period are shown in italics. <b><a href="/about/boxoffice.htm">Click here for a full explanation of the various box office sections</a></b></font><br><br>
# <P ALIGN="CENTER"><A HREF="/yearly/"><FONT FACE="Verdana" SIZE=2><b>back to<br>Yearly Index Page</b></FONT></A></P>
# <br>
# </td><td valign="top" align="center" width="160"><br><br><br><br><br><br><script type="text/javascript">
#     googletag.cmd.push(function() {
#         googletag.defineSlot("/4215/imdb2.bom.other", [[160, 600], [120, 600], [115, 600]], "ad-slot-2").addService(googletag.pubads().setTargeting("p", "rh"));
#         googletag.pubads().enableSingleRequest();
#         googletag.enableServices();
#     });
#     googletag.cmd.push(function() { googletag.display("ad-slot-2"); });
# </script></td></tr></table><table border="0" width="100%" cellspacing="0" cellpadding="3">
# 	<tr>
# 		<td bgcolor="#FFFFFF" align="center"><b><font face="Verdana" size="1"><a href="/yearly/chart/?view=releasedate&view2=domestic&yr=2000&p=.htm">ALL RELEASES</a></font></b></td>
# 		<td bgcolor="#DCDCDC" align="center"><b><font face="Verdana" size="1"><a href="/yearly/chart/?view=widedate&view2=domestic&yr=2000&p=.htm">WIDE RELEASES</font></b></td>
# 		<td bgcolor="#DCDCDC" align="center"><b><font face="Verdana" size="1"><a href="/yearly/chart/?view=limited&view2=domestic&yr=2000&p=.htm">LIMITED RELEASES</font></b></td>
# 				<td bgcolor="#DCDCDC" align="center"><b><font face="Verdana" size="1"><a href="/yearly/chart/?view=calendargross&view2=domestic&yr=2000&p=.htm">CALENDAR GROSSES</font></b></td>
# 			</tr>
# </table>
# <table border="0" cellspacing="0" cellpadding="0" width="100%">
#   <tr><td bgcolor="#8b0000" height="1" colspan="2"><img src="/images/space.gif" border="0" width="1" height="5"></td></tr>
# </table>
#
# </td></tr></table>
#
# 	</div>
# 	</div>
# 	<div id="hp_footer">
# 		<div style="padding-bottom: 20px;">
#
# 			<div style="margin: 0px 121px; vertical-align: top;">
# 				<div id="footer_links">
# 					<ul class="footer_link_list">
# 						<li><strong>Latest Updates</strong></li>
# 						<li><a href="/news/?ref=ft">Movie News</a>
# 						<li><a href="/daily/chart/?ref=ft">Daily Chart</a></li>
# 						<li><a href="/weekend/chart/?ref=ft">Weekend Chart</a></li>
# 						<li><a href="/alltime/?ref=ft">All Time Charts</a></li>
# 						<li><a href="/intl/?ref=ft">International Charts</a></li>
# 					</ul>
# 					<!--
# 					<ul class="footer_link_list">
# 						<li><strong>Popular Movies</strong></li>
# 											</ul>
# 					-->
# 					<ul class="footer_link_list">
# 						<li><strong>Indices</strong></li>
# 						<li><a href="/movies/?ref=ft">Movies A-Z</a></li>
# 						<li><a href="/people/?ref=ft">People</a></li>
# 						<li><a href="/genres/?ref=ft">Genres</a></li>
# 						<li><a href="/franchises/?ref=ft">Franchises</a></li>
# 						<li><a href="/showdowns/?ref=ft">Showdowns</a></li>
# 					</ul>
# 					<ul class="footer_link_list">
# 						<li><strong>Other</strong></li>
# 						<li><a href="/about/?ref=ft">About This Site</a></li>
# 						<li><a href="/about/advertise.htm?ref=ft">Advertising</a></li>
# 						<li><a href="/users/?ref=ft">My Account</a></li>
# 						<li><a href="/about/rss.htm?ref=ft">RSS Feeds</a></li>
# 					</ul>
# 				</div>
# 				<div id="copyright">
# 					<a href="/?ref=ft"><img src="/img/misc/bom_logo1.png" width="245" height="56" alt="Box Office Mojo"></a><br>
# 					<p>An <a href="http://imdb.com/"><img src="/img/misc/IMDbSm.png" width="34" height="16" alt="IMDb" valign="middle"></a> company<br><br></p>
# 					<p>&copy; <a href="http://imdb.com/">IMDb.com</a>, Inc. or its affiliates. All rights reserved. Box Office Mojo and IMDb are trademarks or registered trademarks of IMDb.com, Inc. or its affiliates. <a href="/about/termsofuse.htm">Terms of Use</a> and <a href="/about/privacy.htm">Privacy Policy</a> under which this service is provided to you.</p>
# 					</div>
# 				</div>
# 				<div style="clear:both;">
# 				<div>
# 				 <script type="text/javascript">
#     googletag.cmd.push(function() {
#         googletag.defineSlot("/4215/imdb2.bom.other", [[728, 90]], "ad-slot-3").addService(googletag.pubads().setTargeting("p", "b"));
#         googletag.pubads().enableSingleRequest();
#         googletag.enableServices();
#     });
#     googletag.cmd.push(function() { googletag.display("ad-slot-3"); });
# </script></div>
#
# 				</div>
# 	</div>
# </div>
#
#
#
#
#
# <!-- Page generated in 0.09 seconds | . -->
# <script>
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "6034961" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#   el.parentNode.insertBefore(s, el);
#   })();
# </script>
# <noscript>
#     <img src="http://b.scorecardresearch.com/p?c1=2&c2=6034961&cv=2.0&cj=1" />
# </noscript>
#
# </body>
# </html>
#
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="en">
# <HEAD>
# <TITLE>2001 Yearly Box Office Results - Box Office Mojo</TITLE>
# <META NAME="keywords" CONTENT="2001, year, yearly, box, office, result, list, movie, movies, listing, listings, top movies, all time, film">
# <META NAME="description" CONTENT="Yearly box office results for 2001.">
# <link rel="stylesheet" href="/css/mojo.css?1" type="text/css" media="screen" title="no title" charset="utf-8">
# <link rel="stylesheet" href="/css/mojo.css?1" type="text/css" media="print" title="no title" charset="utf-8"></head>
# <body>
# 	<iframe id="sis_pixel_sitewide" width="1" height="1" frameborder="0" marginwidth="0" marginheight="0" style="display: none;"></iframe>
# <script>
#     setTimeout(function(){
#         try{
#             //sis3.0 pixel
#             var cacheBust = Math.random() * 10000000000000000,
#                 url_sis3 = 'http://s.amazon-adsystem.com/iu3?',
#                 params_sis3 = [
#                     "d=boxofficemojo.com",
#                     "cb=" + cacheBust
#                 ];
#
#             (document.getElementById('sis_pixel_sitewide')).src = url_sis3 + params_sis3.join('&');
#         }catch(e){
#             if (window.ueLogError) {
#                 window.ueLogError(e);
#             }
#         }
#     }, 5);
# </script>
#
# <div id="container">
# <div>
# <script type="text/javascript">
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#
#     (function() {
#         var gads = document.createElement("script");
#         gads.async = true;
#         gads.type = "text/javascript";
#
#         var useSSL = "https:" == document.location.protocol;
#         gads.src = (useSSL ? "https:" : "http:") + "//www.googletagservices.com/tag/js/gpt.js";
#
#         var node = document.getElementsByTagName("script")[0];
#         node.parentNode.insertBefore(gads, node);
#     })();
# </script>
#
# <script type="text/javascript">
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-2831726-1']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     (document.getElementsByTagName('head')[0] || document.getElementsByTagName('body')[0]).appendChild(ga);
#   })();
#
# </script>
#
# 	<div id="hp_banner">
# 	<div id="top_links">
# 		<div style="float: left"><a href="/daily/chart/">Daily Box Office (Wed.)</a> | <a href="/weekend/chart/">Weekend Box Office (Apr. 8&ndash;10)</a> | <a href="/movies/?id=michelledarnell.htm">#1 Movie: 'The Boss'</a> | <a href="http://www.imdb.com/showtimes/?ref_=mojo">Showtimes</a></div>
# 		<div style="float: right">Updated 4/14/2016 10:41 P.M. Pacific Time</div>
# 		<div style="clear:both; height: 0px"></div>
# 	</div>
# </div>
#
# <div id="header">
# 	<div id="leaderboard"><script type="text/javascript">
#     googletag.cmd.push(function() {
#         googletag.defineSlot("/4215/imdb2.bom.other", [[728, 90]], "ad-slot-1").addService(googletag.pubads().setTargeting("p", "t"));
#         googletag.pubads().enableSingleRequest();
#         googletag.enableServices();
#     });
#     googletag.cmd.push(function() { googletag.display("ad-slot-1"); });
# </script></div>	<div id="hp_logo"><a href="/"><img src="/img/misc/bom_logo1.png" width="245" height="56" alt="Box Office Mojo"></a></div>
# 	<div style="clear:both; height: 0px"></div>
# </div>
#
#
# </div>
#
#
# <div id="main">
# <!-- COLUMN 1 of 4 -->
# 	<div id="leftnav">
# <!-- google_ad_section_start(weight=ignore) -->
# <!-- <table id="navleft" cellspacing="0" cellpadding="2" border="0"> -->
# <ul id="leftnav">
# <li class="nl_section">Search Site</li>
# <li class="nl_link" style="padding-left:0px">
# 	<form name="searchbox" method="POST" action="/search/q.php">
# 	<input name="q"  type="text" style="font-size: 9 pt; font-weight: bold; width: 90px;"><br>
# 	<input type="submit" value="Search..." ></form>
# </li>
# <li class='nl_section'>Social</li>
# <li class="nl_link"><a href="http://facebook.com/boxofficemojo" style="vertical-align:middle;"><img src="/images/FaceBook_16x16.png" border="0" alt="Facebook Logo">Facebook</a></li>
# <li class="nl_link"><a href="http://twitter.com/boxofficemojo" style="vertical-align:middle;"><img src="/images/Twitter_16x16.png" border="0" alt="Twitter Logo">Twitter</a></li>
#
# <li class='nl_section'>Features</li>
# <li class='nl_link'><a href="/news/">News</a></li>
# <li class='nl_link'><a href="/schedule/">Release Sched.</a></li>
# <li class='nl_link'><a href="http://www.imdb.com/showtimes?ref_=mojo">Showtimes<br/><span style="margin-left:7px;color: #999999; font-size: 9px;">at <img src="/images/mojo_imdb_sm.png"/></span></a></li>
# <li class='nl_section'>Box Office</li>
# <li class='nl_link'><a href="/daily/">Daily</a></li>
# <li class='nl_link'><a href="/weekend/">Weekend</a></li>
# <li class='nl_link'><a href="/weekly/">Weekly</a></li>
# <li class='nl_link'><a href="/monthly/">Monthly</a></li>
# <li class='nl_link'><a href="/quarterly/">Quarterly</a></li>
# <li class='nl_link'><a href="/seasonal/">Seasonal</a></li>
# <li class='nl_link_current'><a href="/yearly/">Yearly</a></li>
# <li class='nl_link'><a href="/alltime/">All Time</a></li>
# <li class='nl_link'><a href="/chartwatch/">Chart Watch</a></li>
# <li class='nl_link'><a href="/intl/">International</a></li>
# <li class='nl_section'>Indices</li>
# <li class='nl_link'><a href="/movies/">Movies A-Z</a></li>
# <li class='nl_link'><a href="/studio/">Studios</a></li>
# <li class='nl_link'><a href="/people/">People</a></li>
# <li class='nl_link'><a href="/genres/">Genres</a></li>
# <li class='nl_link'><a href="/franchises/">Franchises</a></li>
# <li class='nl_link'><a href="/showdowns/">Showdowns</a></li>
# <li class='nl_link'><a href="/oscar/">Oscar</a></li>
# <li class='nl_link'><a href="/counts/">Theater Counts</a></li>
# </ul>
# </div>
# 	<div id="body">
# 	<div id="addthis"><table border="0" cellspacing="0" cellpadding="0">
# <tr>
# <form method="POST" action="/adjuster.php" name="adjuster">
# <input type="hidden" name="returnURL" value="/yearly/chart/?yr=2001&amp;p=.htm">
# <td valign="center">
#   <font face="Verdana" size="2"><a href="/about/adjuster.htm"><b>Adjuster:</b></a></font>
#   <select size="1" name="ticketyr" style="font-family: Verdana; font-size: 10pt">
#   <option value="0" selected>Actuals</option>
#   <option value="1" >Est. Tckts</option>
# <script language="javascript">
#   for(i=2016; i>=1933; i--) {
#   	document.write('<option value="' + i + '"');
# 	if(i=='0') document.write(' selected');
# 	document.write('>' + i );
# 	if(i=='0') document.write(', $' + '0.00');
# 	document.write('</option>');
#   }
# </script>
#   <option value="1929" >1929</option>
#   <option value="1924" >1924</option>
#   <option value="1910" >1910</option>
#   </select><input type="submit" name="Go" value="Go" style="font-size: 10pt; height: 22">
#
# </td></form></tr></table>
#
# </div>
# 	<h2><a href="/yearly/">Yearly Box Office</a></h2>
#
# 	<table border="0" cellpadding="0" cellspacing="0" width="100%">
# 		<tr><td bgcolor="#8b0000" colspan="2"><img src="/images/space.gif" border="0" width="1" height="5"></td></tr>
# 	</table>
#
# <table border="0" width="100%" cellspacing="0" cellpadding="3">
# 	<tr>
# 		<td bgcolor="#FFFFFF" align="center"><b><font face="Verdana" size="1"><a href="/yearly/chart/?view=releasedate&view2=domestic&yr=2001&p=.htm">ALL RELEASES</a></font></b></td>
# 		<td bgcolor="#DCDCDC" align="center"><b><font face="Verdana" size="1"><a href="/yearly/chart/?view=widedate&view2=domestic&yr=2001&p=.htm">WIDE RELEASES</font></b></td>
# 		<td bgcolor="#DCDCDC" align="center"><b><font face="Verdana" size="1"><a href="/yearly/chart/?view=limited&view2=domestic&yr=2001&p=.htm">LIMITED RELEASES</font></b></td>
# 				<td bgcolor="#DCDCDC" align="center"><b><font face="Verdana" size="1"><a href="/yearly/chart/?view=calendargross&view2=domestic&yr=2001&p=.htm">CALENDAR GROSSES</font></b></td>
# 			</tr>
# </table>
# <table border="0" cellspacing="0" cellpadding="0" width="100%"><tr><td valign="top" align="center"><br>
# <h1>2001 DOMESTIC GROSSES</h1><p>Total Grosses of all Movies Released in 2001</h1></b></FONT></p>
#
# <center><font face="Verdana" size="4"><b><font face="Verdana" size="5">#1&#150;100</font> - <a href="/yearly/chart/?page=2&view=releasedate&view2=domestic&yr=2001&p=.htm">#101&#150;200</a> - <a href="/yearly/chart/?page=3&view=releasedate&view2=domestic&yr=2001&p=.htm">#201&#150;300</a> - <a href="/yearly/chart/?page=4&view=releasedate&view2=domestic&yr=2001&p=.htm">#301&#150;356</a></b></font></center><table border="0" cellspacing="0" cellpadding="0"><tr><td valign="bottom"><font face="Verdana" size="1"><b><a href="/yearly/chart/?yr=2000&view=releasedate&view2=domestic&sort=gross&order=DESC&&p=.htm">&lt; Previous Year</a></b></font></td><td align="center"><table border="0" cellspacing="0" cellpadding="0">
# 					<form method="POST" action="yearly.asof.php" name="asofjump">
# 					<tr><td><font face="Verdana" size="1"><br>Data as of:
# 					<select size="1" name="asof" style="font-size: 8pt">
# 					<option selected value="today">Today</option>
# 					<option  value="sametime">Today in 
# 					<form method="POST" action="yearly.asof.php" name="asofjump">
# 					<tr><td><font face="Verdana" size="1"><br>Data as of:
# 					<select size="1" name="asof" style="font-size: 8pt">
# 					<option selected value="today">Today</option>
# 					<option  value="sametime">Today in 2015</option>
# 					<option value="2015-01-31">Jan. 31, 2015</option>
# 					<option value="2015-02-28">Feb. 28, 2015</option>
# 					<option value="2015-03-31">Mar. 31, 2015</option>
# 					<option value="2015-04-30">Apr. 30, 2015</option>
# 					<option value="2015-05-31">May 31, 2015</option>
# 					<option value="2015-06-30">Jun. 30, 2015</option>
# 					<option value="2015-07-31">Jul. 31, 2015</option>
# 					<option value="2015-08-31">Aug. 31, 2015</option>
# 					<option value="2015-09-30">Sep. 30, 2015</option>
# 					<option value="2015-10-31">Oct. 31, 2015</option>
# 					<option value="2015-11-30">Nov. 30, 2015</option>
# 					<option value="2015-12-31">Dec. 31, 2015</option>
# 					<option value="specify">Specify Date</option>
# 					<option value="about">About this feature</option>
# 					</select> or (<select size="1" name="asof_mo" style="font-size: 8pt">
# 					<option selected value="">Month</option>
#
# 					<option value="01">Jan.</option>
# 					<option value="02">Feb.</option>
# 					<option value="03">Mar.</option>
# 					<option value="04">Apr.</option>
# 					<option value="05">May</option>
# 					<option value="06">Jun.</option>
# 					<option value="07">Jul.</option>
# 					<option value="08">Aug.</option>
# 					<option value="09">Sep.</option>
# 					<option value="10">Oct.</option>
# 					<option value="11">Nov.</option>
# 					<option value="12">Dec.</option>
# 					</select> / <select size="1" name="asof_day" style="font-size: 8pt">
# 					<option selected value="">Day</option>
# 					<option value="01">1</option>
# 					<option value="02">2</option>
# 					<option value="03">3</option>
# 					<option value="04">4</option>
# 					<option value="05">5</option>
# 					<option value="06">6</option>
# 					<option value="07">7</option>
# 					<option value="08">8</option>
# 					<option value="09">9</option>
# 					<option value="10">10</option>
# 					<option value="11">11</option>
# 					<option value="12">12</option>
# 					<option value="13">13</option>
# 					<option value="14">14</option>
# 					<option value="15">15</option>
# 					<option value="16">16</option>
# 					<option value="17">17</option>
# 					<option value="18">18</option>
# 					<option value="19">19</option>
# 					<option value="20">20</option>
# 					<option value="21">21</option>
# 					<option value="22">22</option>
# 					<option value="23">23</option>
# 					<option value="24">24</option>
# 					<option value="25">25</option>
# 					<option value="26">26</option>
# 					<option value="27">27</option>
# 					<option value="28">28</option>
# 					<option value="29">29</option>
# 					<option value="30">30</option>
# 					<option value="31">31</option>
# 					</select> / <select size="1" name="asof_yr" style="font-size: 8pt">
# 						<option selected>2015</option>
# 						<option>2016</option>
# 						</select>) <input type="submit" value="Go" name="go" style="font-size: 8pt; height: 16">
# 					</font></td></tr>
# 					<input type="hidden" name="jumpstuff" value="view=releasedate&view2=domestic&yr=2015&sort=gross&order=DESC&p=.htm">
# 					<input type="hidden" name="curasof" value="today">
# 					<input type="hidden" name="yr" value="2015">
# 					</form>
# 					</table>
# 				</font></td><td valign="bottom" align="right"><font face="Verdana" size="1"><b><a href="/yearly/chart/?yr=2016&view=releasedate&view2=domestic&sort=gross&order=DESC&&p=.htm">Next Year &gt;</a></b></font></td></tr></table><center><font face="Verdana" size="4"><b><font face="Verdana" size="5">#1&#150;100</font> - <a href="/yearly/chart/?page=2&view=releasedate&view2=domestic&yr=2015&p=.htm">#101&#150;200</a> - <a href="/yearly/chart/?page=3&view=releasedate&view2=domestic&yr=2015&p=.htm">#201&#150;300</a> - <a href="/yearly/chart/?page=4&view=releasedate&view2=domestic&yr=2015&p=.htm">#301&#150;400</a> - <a href="/yearly/chart/?page=5&view=releasedate&view2=domestic&yr=2015&p=.htm">#401&#150;500</a> - <a href="/yearly/chart/?page=6&view=releasedate&view2=domestic&yr=2015&p=.htm">#501&#150;600</a> - <a href="/yearly/chart/?page=7&view=releasedate&view2=domestic&yr=2015&p=.htm">#601&#150;698</a></b></font></center><br><font face="Verdana" size="2">Note: <b>RELEASE DATE</b> shows all movies that opened in a given time period and their total grosses. <b>WIDE RELEASES</b> shows only movies released in 600 or more theaters and their total grosses, grouped by wide release date. <b>LIMITED RELEASES</b> shows only movies released in less than 600 theaters and their total grosses, grouped by release date. <b>CALENDAR GROSSES</b> shows all movies playing during the indicated time period, both new and holdover, and their grosses (or estimated grosses) during that time period. Movies released outside the indicated time period are shown in italics. <b><a href="/about/boxoffice.htm">Click here for a full explanation of the various box office sections</a></b></font><br><br>
# <P ALIGN="CENTER"><A HREF="/yearly/"><FONT FACE="Verdana" SIZE=2><b>back to<br>Yearly Index Page</b></FONT></A></P>
# <br>
# </td><td valign="top" align="center" width="160"><br><br><br><br><br><br><script type="text/javascript">
#     googletag.cmd.push(function() {
#         googletag.defineSlot("/4215/imdb2.bom.other", [[160, 600], [120, 600], [115, 600]], "ad-slot-2").addService(googletag.pubads().setTargeting("p", "rh"));
#         googletag.pubads().enableSingleRequest();
#         googletag.enableServices();
#     });
#     googletag.cmd.push(function() { googletag.display("ad-slot-2"); });
# </script></td></tr></table><table border="0" width="100%" cellspacing="0" cellpadding="3">
# 	<tr>
# 		<td bgcolor="#FFFFFF" align="center"><b><font face="Verdana" size="1"><a href="/yearly/chart/?view=releasedate&view2=domestic&yr=2015&p=.htm">ALL RELEASES</a></font></b></td>
# 		<td bgcolor="#DCDCDC" align="center"><b><font face="Verdana" size="1"><a href="/yearly/chart/?view=widedate&view2=domestic&yr=2015&p=.htm">WIDE RELEASES</font></b></td>
# 		<td bgcolor="#DCDCDC" align="center"><b><font face="Verdana" size="1"><a href="/yearly/chart/?view=limited&view2=domestic&yr=2015&p=.htm">LIMITED RELEASES</font></b></td>
# 				<td bgcolor="#DCDCDC" align="center"><b><font face="Verdana" size="1"><a href="/yearly/chart/?view=calendargross&view2=domestic&yr=2015&p=.htm">CALENDAR GROSSES</font></b></td>
# 			</tr>
# </table>
# <table border="0" cellspacing="0" cellpadding="0" width="100%">
#   <tr><td bgcolor="#8b0000" height="1" colspan="2"><img src="/images/space.gif" border="0" width="1" height="5"></td></tr>
# </table>
#
# </td></tr></table>
#
# 	</div>
# 	</div>
# 	<div id="hp_footer">
# 		<div style="padding-bottom: 20px;">
#
# 			<div style="margin: 0px 121px; vertical-align: top;">
# 				<div id="footer_links">
# 					<ul class="footer_link_list">
# 						<li><strong>Latest Updates</strong></li>
# 						<li><a href="/news/?ref=ft">Movie News</a>
# 						<li><a href="/daily/chart/?ref=ft">Daily Chart</a></li>
# 						<li><a href="/weekend/chart/?ref=ft">Weekend Chart</a></li>
# 						<li><a href="/alltime/?ref=ft">All Time Charts</a></li>
# 						<li><a href="/intl/?ref=ft">International Charts</a></li>
# 					</ul>
# 					<!--
# 					<ul class="footer_link_list">
# 						<li><strong>Popular Movies</strong></li>
# 											</ul>
# 					-->
# 					<ul class="footer_link_list">
# 						<li><strong>Indices</strong></li>
# 						<li><a href="/movies/?ref=ft">Movies A-Z</a></li>
# 						<li><a href="/people/?ref=ft">People</a></li>
# 						<li><a href="/genres/?ref=ft">Genres</a></li>
# 						<li><a href="/franchises/?ref=ft">Franchises</a></li>
# 						<li><a href="/showdowns/?ref=ft">Showdowns</a></li>
# 					</ul>
# 					<ul class="footer_link_list">
# 						<li><strong>Other</strong></li>
# 						<li><a href="/about/?ref=ft">About This Site</a></li>
# 						<li><a href="/about/advertise.htm?ref=ft">Advertising</a></li>
# 						<li><a href="/users/?ref=ft">My Account</a></li>
# 						<li><a href="/about/rss.htm?ref=ft">RSS Feeds</a></li>
# 					</ul>
# 				</div>
# 				<div id="copyright">
# 					<a href="/?ref=ft"><img src="/img/misc/bom_logo1.png" width="245" height="56" alt="Box Office Mojo"></a><br>
# 					<p>An <a href="http://imdb.com/"><img src="/img/misc/IMDbSm.png" width="34" height="16" alt="IMDb" valign="middle"></a> company<br><br></p>
# 					<p>&copy; <a href="http://imdb.com/">IMDb.com</a>, Inc. or its affiliates. All rights reserved. Box Office Mojo and IMDb are trademarks or registered trademarks of IMDb.com, Inc. or its affiliates. <a href="/about/termsofuse.htm">Terms of Use</a> and <a href="/about/privacy.htm">Privacy Policy</a> under which this service is provided to you.</p>
# 					</div>
# 				</div>
# 				<div style="clear:both;">
# 				<div>
# 				 <script type="text/javascript">
#     googletag.cmd.push(function() {
#         googletag.defineSlot("/4215/imdb2.bom.other", [[728, 90]], "ad-slot-3").addService(googletag.pubads().setTargeting("p", "b"));
#         googletag.pubads().enableSingleRequest();
#         googletag.enableServices();
#     });
#     googletag.cmd.push(function() { googletag.display("ad-slot-3"); });
# </script></div>
#
# 				</div>
# 	</div>
# </div>
#
#
#
#
#
# <!-- Page generated in 0.08 seconds | . -->
# <script>
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "6034961" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#   el.parentNode.insertBefore(s, el);
#   })();
# </script>
# <noscript>
#     <img src="http://b.scorecardresearch.com/p?c1=2&c2=6034961&cv=2.0&cj=1" />
# </noscript>
#
# </body>
# </html>

# %%
rawdict = get_movie_values(pages, field_names)

# %%
# Out:
# 1600

# %%
title = get_title(pages)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="en">
# <head>
# <meta http-equiv="Content-type" content="text/html;charset=iso-8859-1">
# <title>How the Grinch Stole Christmas (2000) - Box Office Mojo</title>
#
# <style type="text/css">
# table.chart-wide { width: 100%; }
# </style>
# <META name="keywords" content="how the grinch stole christmas, movie, film, box office, result, records, charts, revenue, opening weekend, gross, worldwide, overseas, foreign, news, reviews, articles, stories, story, analysis, revenue, release date, mpaa rating, genre, running time, length, budget, production budget, distributor, studio, universal, theatrical summary, theatrical, daily box office results, weekend box office results, weekly box office, weekly box office, international box office summary, worldwide box office summary, similar movies, box office mojo">
# <META name="description" content="How the Grinch Stole Christmas summary of box office results, charts and release information and related links.">
#
# <link rel="stylesheet" href="/css/mojo.css?1" type="text/css" media="screen" title="no title" charset="utf-8">
# <link rel="stylesheet" href="/css/mojo.css?1" type="text/css" media="print" title="no title" charset="utf-8">
# <script type="text/javascript" src="/js/jscharts.js"></script>
# </head>
# <body>
# <iframe id="sis_pixel_sitewide" width="1" height="1" frameborder="0" marginwidth="0" marginheight="0" style="display: none;"></iframe>
# <script>
#     setTimeout(function(){
#         try{
#             //sis3.0 pixel
#             var cacheBust = Math.random() * 10000000000000000,
#                 url_sis3 = 'http://s.amazon-adsystem.com/iu3?',
#                 params_sis3 = [
#                     "d=boxofficemojo.com",
#                     "cb=" + cacheBust
#                 ];
#
#             (document.getElementById('sis_pixel_sitewide')).src = url_sis3 + params_sis3.join('&');
#         }catch(e){
#             if (window.ueLogError) {
#                 window.ueLogError(e);
#             }
#         }
#     }, 5);
# </script>
#
# <div id="container">
# <div>
# <script type="text/javascript">
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#
#     (function() {
#         var gads = document.createElement("script");
#         gads.async = true;
#         gads.type = "text/javascript";
#
#         var useSSL = "https:" == document.location.protocol;
#         gads.src = (useSSL ? "https:" : "http:") + "//www.googletagservices.com/tag/js/gpt.js";
#
#         var node = document.getElementsByTagName("script")[0];
#         node.parentNode.insertBefore(gads, node);
#     })();
# </script>
#
# <script type="text/javascript">
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-2831726-1']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     (document.getElementsByTagName('head')[0] || document.getElementsByTagName('body')[0]).appendChild(ga);
#   })();
#
# </script>
#
# 	<div id="hp_banner">
# 	<div id="top_links">
# 		<div style="float: left"><a href="/daily/chart/">Daily Box Office (Wed.)</a> | <a href="/weekend/chart/">Weekend Box Office (Apr. 8&ndash;10)</a> | <a href="/movies/?id=michelledarnell.htm">#1 Movie: 'The Boss'</a> | <a href="http://www.imdb.com/showtimes/?ref_=mojo">Showtimes</a></div>
# 		<div style="float: right">Updated 4/14/2016 10:41 P.M. Pacific Time</div>
# 		<div style="clear:both; height: 0px"></div>
# 	</div>
# </div>
#
# <div id="header">
# 	<div id="leaderboard"><script type="text/javascript">
#     googletag.cmd.push(function() {
#         googletag.defineSlot("/4215/imdb2.bom.movie", [[728, 90]], "ad-slot-1").addService(googletag.pubads().setTargeting("p", "t"));
#         googletag.pubads().enableSingleRequest();
#         googletag.enableServices();
#     });
#     googletag.cmd.push(function() { googletag.display("ad-slot-1"); });
# </script></div>	<div id="hp_logo"><a href="/"><img src="/img/misc/bom_logo1.png" width="245" height="56" alt="Box Office Mojo"></a></div>
# 	<div style="clear:both; height: 0px"></div>
# </div>
#
#
# </div>
#
#
# <div id="main">
# <!-- COLUMN 1 of 4 -->
# 	<div id="leftnav">
# <!-- google_ad_section_start(weight=ignore) -->
# <!-- <table id="navleft" cellspacing="0" cellpadding="2" border="0"> -->
# <ul id="leftnav">
# <li class="nl_section">Search Site</li>
# <li class="nl_link" style="padding-left:0px">
# 	<form name="searchbox" method="POST" action="/search/q.php">
# 	<input name="q"  type="text" style="font-size: 9 pt; font-weight: bold; width: 90px;"><br>
# 	<input type="submit" value="Search..." ></form>
# </li>
# <li class='nl_section'>Social</li>
# <li class="nl_link"><a href="http://facebook.com/boxofficemojo" style="vertical-align:middle;"><img src="/images/FaceBook_16x16.png" border="0" alt="Facebook Logo">Facebook</a></li>
# <li class="nl_link"><a href="http://twitter.com/boxofficemojo" style="vertical-align:middle;"><img src="/images/Twitter_16x16.png" border="0" alt="Twitter Logo">Twitter</a></li>
#
# <li class='nl_section'>Features</li>
# <li class='nl_link'><a href="/news/">News</a></li>
# <li class='nl_link'><a href="/schedule/">Release Sched.</a></li>
# <li class='nl_link'><a href="http://www.imdb.com/showtimes?ref_=mojo">Showtimes<br/><span style="margin-left:7px;color: #999999; font-size: 9px;">at <img src="/images/mojo_imdb_sm.png"/></span></a></li>
# <li class='nl_section'>Box Office</li>
# <li class='nl_link'><a href="/daily/">Daily</a></li>
# <li class='nl_link'><a href="/weekend/">Weekend</a></li>
# <li class='nl_link'><a href="/weekly/">Weekly</a></li>
# <li class='nl_link'><a href="/monthly/">Monthly</a></li>
# <li class='nl_link'><a href="/quarterly/">Quarterly</a></li>
# <li class='nl_link'><a href="/seasonal/">Seasonal</a></li>
# <li class='nl_link'><a href="/yearly/">Yearly</a></li>
# <li class='nl_link'><a href="/alltime/">All Time</a></li>
# <li class='nl_link'><a href="/chartwatch/">Chart Watch</a></li>
# <li class='nl_link'><a href="/intl/">International</a></li>
# <li class='nl_section'>Indices</li>
# <li class='nl_link_current'><a href="/movies/">Movies A-Z</a></li>
# <li class='nl_link'><a href="/studio/">Studios</a></li>
# <li class='nl_link'><a href="/people/">People</a></li>
# <li class='nl_link'><a href="/genres/">Genres</a></li>
# <li class='nl_link'><a href="/franchises/">Franchises</a></li>
# <li class='nl_link'><a href="/showdowns/">Showdowns</a></li>
# <li class='nl_link'><a href="/oscar/">Oscar</a></li>
# <li class='nl_link'><a href="/counts/">Theater Counts</a></li>
# </ul>
# </div>
# 	<div id="body">
#
# 	<table border="0" width="878px" cellspacing="0">
# 	<tr>
# 	<td align="right" style="whitespace:nowrap;">
#
#
# 	<table border="0" cellspacing="0" cellpadding="0">
# <tr>
# <form method="POST" action="/adjuster.php" name="adjuster">
# <input type="hidden" name="returnURL" value="/movies/?id=grinch.htm">
# <td valign="center">
#   <font face="Verdana" size="2"><a href="/about/adjuster.htm"><b>Adjuster:</b></a></font>
#   <select size="1" name="ticketyr" style="font-family: Verdana; font-size: 10pt">
#   <option value="0" selected>Actuals</option>
#   <option value="1" >Est. Tckts</option>
# <script language="javascript">
#   for(i=2016; i>=1933; i--) {
#   	document.write('<option value="' + i + '"');
# 	if(i=='0') document.write(' selected');
# 	document.write('>' + i );
# 	if(i=='0') document.write(', $' + '0.00');
# 	document.write('</option>');
#   }
# </script>
#   <option value="1929" >1929</option>
#   <option value="1924" >1924</option>
#   <option value="1910" >1910</option>
#   </select><input type="submit" name="Go" value="Go" style="font-size: 10pt; height: 22">
#
# </td></form></tr></table>
#
# </td></tr>
# 	<!--------------------------Site Body---------------------------------->
#
# <tr></td>
#
# <table cellspacing="0" cellpadding="0" border="0" width="100%">
# 	<tr>	<td valign="top">
# 		<table border="0" cellpadding="0" cellspacing="0" width="100%" style="padding-top: 5px;"><tr><td valign="top" align="center">
# 		<a href="/movies/?page=media&id=grinch.htm"><img src="http://ia.media-imdb.com/images/M/MV5BMTM2NzgzNTk2Nl5BMl5BanBnXkFtZTcwMjUxNjUyMQ@@._V1_UY222_CR0,0,150,222_AL.jpg" border="1" style="border-color: 000000"></a>	</td>
# 	<td valign="top" align="center"><br><font face="Verdana" size="5"><b>How the Grinch Stole Christmas</b></font><br><br>
# 	<table border="0" cellspacing="0" cellpadding="0"><tr><td>
# 	<center><table border="0" border="0" cellspacing="1" cellpadding="4" bgcolor="#dcdcdc" width="95%"><tr bgcolor="#ffffff"><td align="center" colspan="2"><font size="4">Domestic Total Gross: <b>$260,044,825</b></font></td></tr><tr bgcolor="#ffffff"><td valign="top">Distributor: <b><a href="/studio/chart/?studio=universal.htm">Universal</a></b></td><td valign="top">Release Date: <b><nobr><a href="/schedule/?view=bydate&release=theatrical&date=2000-11-17&p=.htm">November 17, 2000</a></nobr></b></td></tr><tr bgcolor="#ffffff"><td valign="top">Genre: <b>Family Comedy</b></td><td valign="top">Runtime: <b>1 hrs. 44 min.</b></td></tr><tr bgcolor="#ffffff"><td valign="top">MPAA Rating: <b>PG</b></td><td valign="top">Production Budget: <b>$123 million</b></td></tr></table>	</td>
# 	</tr></table></td>
# 	<td align="right"><script type="text/javascript">
#     googletag.cmd.push(function() {
#         googletag.defineSlot("/4215/imdb2.bom.movie", [[300, 250]], "ad-slot-2").addService(googletag.pubads().setTargeting("p", "rh"));
#         googletag.pubads().enableSingleRequest();
#         googletag.enableServices();
#     });
#     googletag.cmd.push(function() { googletag.display("ad-slot-2"); });
# </script></td>
# 	</tr>
# </table>
#
#
# <table cellspacing="0" cellpadding="0" border="0" width="878px">
# 	<tr><td>
#
# <ul class="nav_tabs">
# <li class="nav_tab_current"><a href="/movies/?page=main&id=grinch.htm">Summary</a></li>
# <li><a href="/movies/?page=daily&id=grinch.htm">Daily</a></li>
# <li><a href="/movies/?page=weekend&id=grinch.htm">Weekend</a></li>
# <li><a href="/movies/?page=weekly&id=grinch.htm">Weekly</a></li>
# <li><a href="/movies/?page=intl&id=grinch.htm">Foreign</a></li>
# <li><a href="/movies/?page=similar&id=grinch.htm">Similar Movies</a></li>
# </ul>
# <br />
# </td></tr>
# <tr><td>
#
# <table border="0" cellspacing="0" cellpadding="0" width="100%">
# 	<tr><td valign="top" width="434px">
# 	<table border="0" cellpadding="0" cellspacing="0" width="100%"><tr>
# 		<td width="50%" valign="top">
# <div class="mp_box">
# <div class="mp_box_tab">Total Lifetime Grosses</b></div>
# <div class="mp_box_content">
# 	<table border="0" cellspacing="0" cellpadding="0">
# 		<tr>
# 			<td width="40%"><b>Domestic:</b></td>
# 			<td width="35%" align="right">&nbsp;<b>$260,044,825</b></td>
# 						<td width="25%" align="right">&nbsp;&nbsp;&nbsp;<b>75.3%</b></td>
# 					</tr>
# 				<tr>
# 			<td width="40%">+&nbsp;<a href="/movies/?page=intl&id=grinch.htm">Foreign:</a></td>
# 			<td width="35%" align="right">&nbsp;$85,096,578</td>
# 			<td width="25%" align="right">&nbsp;&nbsp;&nbsp;24.7%</td>
# 		</tr>
# 		<tr>
# 			<td width="100%" colspan="3"><hr></td>
# 		</tr>
# 		<tr>
# 			<td width="40%">=&nbsp;<b>Worldwide:</b></td>
# 			<td width="35%" align="right">&nbsp;<b>$345,141,403</b></td>
# 			<td width="25%">&nbsp;</td>
# 		</tr>
# 			</table>
# 	</div>
# </div>
#
#
# <div class="mp_box">
# 	<div class="mp_box_tab">Domestic Summary</b></div>
# 	<div class="mp_box_content">
#
# 		<table border="0" cellspacing="0" cellpadding="0">
# 		<tr>
# 			<td align="center"><a href="/weekend/chart/?yr=2000&wknd=46&p=.htm">Opening&nbsp;Weekend:</a></td><td>&nbsp;$55,082,330</td></tr>
# 		<tr>
# 			<td align="center" colspan="2"><font size="2">(#1 rank, 3,127 theaters, $17,615 average)</font></td></tr>
# 		<tr>
# 			<td align="right">%&nbsp;of&nbsp;Total&nbsp;Gross:</td><td>&nbsp;21.2%</td></tr>
# 		<tr><td align="right" colspan="2"><font face="Helvetica, Arial, Sans-Serif" size="1"><a href="/movies/?page=weekend&id=grinch.htm"><b>&gt; View All 15 Weekends</b></a></font></td></tr>
#
# 		</table>
#
#
#
# 		<table border="0" cellspacing="0" cellpadding="0">
# 		<tr>
# 			<td>Widest&nbsp;Release:</td>
# 			<td>&nbsp;3,256 theaters</td>
# 		</tr>
# 		</table>
#
#
# 		<table border="0" cellspacing="0" cellpadding="0">
# 		<tr>
# 			<td>Close&nbsp;Date:</td>
# 			<td>&nbsp;March 1, 2001</td>
# 		</tr>
# 		</table>
#
#
# 		<table border="0" cellspacing="0" cellpadding="0">
# 		<tr>
# 			<td>In Release:</td>
# 			<td>&nbsp;105 days / 15 weeks</td>
# 		</tr>
# 		</table>
#
#
#
#
# 	</div>
# </div>
# </td>
# 		<td valign="top" style="padding-left: 10px;"><div class="mp_box">
# 	<div class="mp_box_tab">The Players</div>
# 	<div class="mp_box_content">
# 	<table>
# 		</td></tr><tr><td valign="top" align="right"><font size="2"><a href="/people/?view=Director&p=.htm">Director:</font></a></td><td><font size="2"><a href="/people/chart/?view=Director&id=ronhoward.htm">Ron Howard</a></font></td></tr><tr><td valign="top" align="right"><font size="2"><a href="/people/?view=Actor&p=.htm">Actors:</font></a></td><td><font size="2"><a href="/people/chart/?view=Actor&id=jimcarrey.htm">Jim Carrey</a><br><a href="/people/chart/?view=Actor&id=anthonyhopkins.htm">Anthony Hopkins*</a> <font size="2">(Narrator)</font></font></td></tr><tr><td valign="top" align="right"><font size="2"><a href="/people/?view=Producer&p=.htm">Producers:</font></a></td><td><font size="2"><a href="/people/chart/?view=Producer&id=briangrazer.htm">Brian Grazer</a><br><a href="/people/chart/?view=Producer&id=ronhoward.htm">Ron Howard</a></font></td></tr><tr><td valign="top" align="right"><font size="2"><a href="/people/?view=Composer&p=.htm">Composer:</font></a></td><td><font size="2"><a href="/people/chart/?view=Composer&id=jameshorner.htm">James Horner</a></font></td></tr><tr><td colspan="2" align="right"><i><small>* Denotes minor role</small></i></table></div></div></td>
# 	</tr></table>
# 		<div class="mp_box">
# 			<div class="mp_box_tab">2000 Academy Awards&reg;</div>
# 			<div class="mp_box_content"><table border="0" cellspacing="0" cellpadding="5" width="100%"><tr><td><a href="/oscar/movies/?id=grinch.htm"><b>Nominated for Three Oscars, Including One Win.</b><br/>View full award breakdown...</a></td></tr></table></div></div><div class="mp_box">
# 	<div class="mp_box_tab">Genres</div>
# 	<div class="mp_box_content">
# 			<table border="0" cellspacing="1" cellpadding="5" style="border-collapse: collapse" width="100%">
# 				<tr><th>Genre</th>
# 					<th>Rank</th></tr>
# <tr bgcolor="#ffffff"><td><font size="2"><a href="/genres/chart/?id=christmas.htm"><b>Christmas</b></a></font></td>
# <td align="center"><font size="2"><b>2</b></font></td>
# </tr>
#
# <tr bgcolor="#f4f4ff"><td><font size="2"><a href="/genres/chart/?id=childrensbook.htm">Family - Children's Book Adaptation</a></font></td>
# <td align="center"><font size="2">11</font></td>
# </tr>
#
# 					</table>
# </div></div>
#
# <div class="mp_box">
# 	<div class="mp_box_tab">Franchises</div>
# 	<div class="mp_box_content">
# 					<table border="0" cellspacing="1" cellpadding="5" style="border-collapse: collapse" width="100%">
#
width="1" height="1" border="0" alt="" style="border:none !important; margin:0px !important;" /></li>
# </ul></div></div>	<OBJECT classid="clsid:D27CDB6E-AE6D-11cf-96B8-444553540000" codebase="http://fpdownload.macromedia.com/get/flashplayer/current/swflash.cab" id="Player_82160f42-9620-4d0a-b79a-18b1abd853fb"  WIDTH="400px" HEIGHT="150px"> <PARAM NAME="movie" VALUE="http://ws.amazon.com/widgets/q?ServiceVersion=20070822&MarketPlace=US&ID=V20070822%2FUS%2Fboxofficemojo-20%2F8010%2F82160f42-9620-4d0a-b79a-18b1abd853fb&Operation=GetDisplayTemplate"><PARAM NAME="quality" VALUE="high"><PARAM NAME="bgcolor" VALUE="#FFFFFF"><PARAM NAME="allowscriptaccess" VALUE="always"><embed src="http://ws.amazon.com/widgets/q?ServiceVersion=20070822&MarketPlace=US&ID=V20070822%2FUS%2Fboxofficemojo-20%2F8010%2F82160f42-9620-4d0a-b79a-18b1abd853fb&Operation=GetDisplayTemplate" id="Player_82160f42-9620-4d0a-b79a-18b1abd853fb" quality="high" bgcolor="#ffffff" name="Player_82160f42-9620-4d0a-b79a-18b1abd853fb" allowscriptaccess="always"  type="application/x-shockwave-flash" align="middle" height="150px" width="400px"></embed></OBJECT> <NOSCRIPT><A HREF="http://ws.amazon.com/widgets/q?ServiceVersion=20070822&MarketPlace=US&ID=V20070822%2FUS%2Fboxofficemojo-20%2F8010%2F82160f42-9620-4d0a-b79a-18b1abd853fb&Operation=NoScript">Amazon.com Widgets</A></NOSCRIPT>
#
# </td>
# </tr>
# </table>
#
# <br>
# </td>
# </tr>
# </table>
#
#
# </td></tr></table>
# 	</div>
# 	</div>
# 	<div id="hp_footer">
# 		<div style="padding-bottom: 20px;">
#
# 			<div style="margin: 0px 121px; vertical-align: top;">
# 				<div id="footer_links">
# 					<ul class="footer_link_list">
# 						<li><strong>Latest Updates</strong></li>
# 						<li><a href="/news/?ref=ft">Movie News</a>
# 						<li><a href="/daily/chart/?ref=ft">Daily Chart</a></li>
# 						<li><a href="/weekend/chart/?ref=ft">Weekend Chart</a></li>
# 						<li><a href="/alltime/?ref=ft">All Time Charts</a></li>
# 						<li><a href="/intl/?ref=ft">International Charts</a></li>
# 					</ul>
# 					<!--
# 					<ul class="footer_link_list">
# 						<li><strong>Popular Movies</strong></li>
# 											</ul>
# 					-->
# 					<ul class="footer_link_list">
# 						<li><strong>Indices</strong></li>
# 						<li><a href="/movies/?ref=ft">Movies A-Z</a></li>
# 						<li><a href="/people/?ref=ft">People</a></li>
# 						<li><a href="/genres/?ref=ft">Genres</a></li>
# 						<li><a href="/franchises/?ref=ft">Franchises</a></li>
# 						<li><a href="/showdowns/?ref=ft">Showdowns</a></li>
# 					</ul>
# 					<ul class="footer_link_list">
# 						<li><strong>Other</strong></li>
# 						<li><a href="/about/?ref=ft">About This Site</a></li>
# 						<li><a href="/about/advertise.htm?ref=ft">Advertising</a></li>
# 						<li><a href="/users/?ref=ft">My Account</a></li>
# 						<li><a href="/about/rss.htm?ref=ft">RSS Feeds</a></li>
# 					</ul>
# 				</div>
# 				<div id="copyright">
# 					<a href="/?ref=ft"><img src="/img/misc/bom_logo1.png" width="245" height="56" alt="Box Office Mojo"></a><br>
# 					<p>An <a href="http://imdb.com/"><img src="/img/misc/IMDbSm.png" width="34" height="16" alt="IMDb" valign="middle"></a> company<br><br></p>
# 					<p>&copy; <a href="http://imdb.com/">IMDb.com</a>, Inc. or its affiliates. All rights reserved. Box Office Mojo and IMDb are trademarks or registered trademarks of IMDb.com, Inc. or its affiliates. <a href="/about/termsofuse.htm">Terms of Use</a> and <a href="/about/privacy.htm">Privacy Policy</a> under which this service is provided to you.</p>
# 					</div>
# 				</div>
# 				<div style="clear:both;">
# 				<div>
# 				 <script type="text/javascript">
#     googletag.cmd.push(function() {
#         googletag.defineSlot("/4215/imdb2.bom.movie", [[728, 90]], "ad-slot-3").addService(googletag.pubads().setTargeting("p", "b"));
#         googletag.pubads().enableSingleRequest();
#         googletag.enableServices();
#     });
#     googletag.cmd.push(function() { googletag.display("ad-slot-3"); });
# </script></div>
#
# 				</div>
# 	</div>
# </div>
#
#
#
#
#
# <!-- Page generated in 0.06 seconds | . -->
# <script>
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "6034961" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#   el.parentNode.insertBefore(s, el);
#   })();
# </script>
# <noscript>
#     <img src="http://b.scorecardresearch.com/p?c1=2&c2=6034961&cv=2.0&cj=1" />
# </noscript>
# </body>
# </html>
#
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="en">
# <head>
# <meta http-equiv="Content-type" content="text/html;charset=iso-8859-1">
# <title>Cast Away (2000) - Box Office Mojo</title>
#
# <style type="text/css">
# table.chart-wide { width: 100%; }
# </style>
# <META name="keywords" content="cast away, movie, film, box office, result, records, charts, revenue, opening weekend, gross, worldwide, overseas, foreign, news, reviews, articles, stories, story, analysis, revenue, release date, mpaa rating, genre, running time, length, budget, production budget, distributor, studio, fox, theatrical summary, theatrical, daily box office results, weekend box office results, weekly box office, weekly box office, international box office summary, worldwide box office summary, similar movies, box office mojo">
# <META name="description" content="Cast Away summary of box office results, charts and release information and related links.">
#
# <link rel="stylesheet" href="/css/mojo.css?1" type="text/css" media="screen" title="no title" charset="utf-8">
# <link rel="stylesheet" href="/css/mojo.css?1" type="text/css" media="print" title="no title" charset="utf-8">
# <script type="text/javascript" src="/js/jscharts.js"></script>
# </head>
# <body>
# <iframe id="sis_pixel_sitewide" width="1" height="1" frameborder="0" marginwidth="0" marginheight="0" style="display: none;"></iframe>
# <script>
#     setTimeout(function(){
#         try{
#             //sis3.0 pixel
#             var cacheBust = Math.random() * 10000000000000000,
#                 url_sis3 = 'http://s.amazon-adsystem.com/iu3?',
#                 params_sis3 = [
#                     "d=boxofficemojo.com",
#                     "cb=" + cacheBust
#                 ];
#
#             (document.getElementById('sis_pixel_sitewide')).src = url_sis3 + params_sis3.join('&');
#         }catch(e){
#             if (window.ueLogError) {
#                 window.ueLogError(e);
#             }
#         }
#     }, 5);
# </script>
#
# <div id="container">
# <div>
# <script type="text/javascript">
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#
#     (function() {
#         var gads = document.createElement("script");
#         gads.async = true;
#         gads.type = "text/javascript";
#
#         var useSSL = "https:" == document.location.protocol;
#         gads.src = (useSSL ? "https:" : "http:") + "//www.googletagservices.com/tag/js/gpt.js";
#
#         var node = document.getElementsByTagName("script")[0];
#         node.parentNode.insertBefore(gads, node);
#     })();
# </script>
#
# <script type="text/javascript">
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-2831726-1']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     (document.getElementsByTagName('head')[0] || document.getElementsByTagName('body')[0]).appendChild(ga);
#   })();
#
# </script>
#
# 	<div id="hp_banner">
# 	<div id="top_links">
# 		<div style="float: left"><a href="/daily/chart/">Daily Box Office (Wed.)</a> | <a href="/weekend/chart/">Weekend Box Office (Apr. 8&ndash;10)</a> | <a href="/movies/?id=michelledarnell.htm">#1 Movie: 'The Boss'</a> | <a href="http://www.imdb.com/showtimes/?ref_=mojo">Showtimes</a></div>
# 		<div style="float: right">Updated 4/14/2016 10:41 P.M. Pacific Time</div>
# 		<div style="clear:both; height: 0px"></div>
# 	</div>
# </div>
#
# <div id="header">
# 	<div id="leaderboard"><script type="text/javascript">
#     googletag.cmd.push(function() {
#         googletag.defineSlot("/4215/imdb2.bom.movie", [[728, 90]], "ad-slot-1").addService(googletag.pubads().setTargeting("p", "t"));
#         googletag.pubads().enableSingleRequest();
#         googletag.enableServices();
#     });
#     googletag.cmd.push(function() { googletag.display("ad-slot-1"); });
# </script></div>	<div id="hp_logo"><a href="/"><img src="/img/misc/bom_logo1.png" width="245" height="56" alt="Box Office Mojo"></a></div>
# 	<div style="clear:both; height: 0px"></div>
# </div>
#
#
# </div>
#
#
# <div id="main">
# <!-- COLUMN 1 of 4 -->
# 	<div id="leftnav">
# <!-- google_ad_section_start(weight=ignore) -->
# <!-- <table id="navleft" cellspacing="0" cellpadding="2" border="0"> -->
# <ul id="leftnav">
# <li class="nl_section">Search Site</li>
# <li class="nl_link" style="padding-left:0px">
# 	<form name="searchbox" method="POST" action="/search/q.php">
# 	<input name="q"  type="text" style="font-size: 9 pt; font-weight: bold; width: 90px;"><br>
# 	<input type="submit" value="Search..." ></form>
# </li>
# <li class='nl_section'>Social</li>
# <li class="nl_link"><a href="http://facebook.com/boxofficemojo" style="vertical-align:middle;"><img src="/images/FaceBook_16x16.png" border="0" alt="Facebook Logo">Facebook</a></li>
# <li class="nl_link"><a href="http://twitter.com/boxofficemojo" style="vertical-align:middle;"><img src="/images/Twitter_16x16.png" border="0" alt="Twitter Logo">Twitter</a></li>
#
# <li class='nl_section'>Features</li>
# <li class='nl_link'><a href="/news/">News</a></li>
# <li class='nl_link'><a href="/schedule/">Release Sched.</a></li>
# <li class='nl_link'><a href="http://www.imdb.com/showtimes?ref_=mojo">Showtimes<br/><span style="margin-left:7px;color: #999999; font-size: 9px;">at <img src="/images/mojo_imdb_sm.png"/></span></a></li>
# <li class='nl_section'>Box Office</li>
# <li class='nl_link'><a href="/daily/">Daily</a></li>
# <li class='nl_link'><a href="/weekend/">Weekend</a></li>
# <li class='nl_link'><a href="/weekly/">Weekly</a></li>
# <li class='nl_link'><a href="/monthly/">Monthly</a></li>
# <li class='nl_link'><a href="/quarterly/">Quarterly</a></li>
# <li class='nl_link'><a href="/seasonal/">Seasonal</a></li>
# <li class='nl_link'><a href="/yearly/">Yearly</a></li>
# <li class='nl_link'><a href="/alltime/">All Time</a></li>
# <li class='nl_link'><a href="/chartwatch/">Chart Watch</a></li>
# <li class='nl_link'><a href="/intl/">International</a></li>
# <li class='nl_section'>Indices</li>
# <li class='nl_link_current'><a href="/movies/">Movies A-Z</a></li>
# <li class='nl_link'><a href="/studio/">Studios</a></li>
# <li class='nl_link'><a href="/people/">People</a></li>
# <li class='nl_link'><a href="/genres/">Genres</a></li>
# <li class='nl_link'><a href="/franchises/">Franchises</a></li>
# <li class='nl_link'><a href="/showdowns/">Showdowns</a></li>
# <li class='nl_link'><a href="/oscar/">Oscar</a></li>
# <li class='nl_link'><a href="/counts/">Theater Counts</a></li>
# </ul>
# </div>
# 	<div id="body">
#
# 	<table border="0" width="878px" cellspacing="0">
# 	<tr>
# 	<td align="right" style="whitespace:nowrap;">
#
#
# 	<table border="0" cellspacing="0" cellpadding="0">
# <tr>
# <form method="POST" action="/adjuster.php" name="adjuster">
# <input type="hidden" name="returnURL" value="/movies/?id=castaway.htm">
# <td valign="center">
#   <font face="Verdana" size="2"><a href="/about/adjuster.htm"><b>Adjuster:</b></a></font>
#   <select size="1" name="ticketyr" style="font-family: Verdana; font-size: 10pt">
#   <option value="0" selected>Actuals</option>
#   <option value="1" >Est. Tckts</option>
# <script language="javascript">
#   for(i=2016; i>=1933; i--) {
#   	document.write('<option value="' + i + '"');
# 	if(i=='0') document.write(' selected');
# 	document.write('>' + i );
# 	if(i=='0') document.write(', $' + '0.00');
# 	document.write('</option>');
#   }
# </script>
#   <option value="1929" >1929</option>
#   <option value="1924" >1924</option>
#   <option value="1910" >1910</option>
#   </select><input type="submit" name="Go" value="Go" style="font-size: 10pt; height: 22">
#
# </td></form></tr></table>
#
# </td></tr>
# 	<!--------------------------Site Body---------------------------------->
#
# <tr></td>
#
# <table cellspacing="0" cellpadding="0" border="0" width="100%">
# 	<tr>	<td valign="top">
# 		<table border="0" cellpadding="0" cellspacing="0" width="100%" style="padding-top: 5px;"><tr><td valign="top" align="center">
# 		<a href="/movies/?page=media&id=castaway.htm"><img src="http://ia.media-imdb.com/images/M/MV5BMTI2MDY0ODEwNF5BMl5BanBnXkFtZTYwMDI2NTk4._V1_UY222_CR0,0,150,222_AL.jpg" border="1" style="border-color: 000000"></a>	</td>
# 	<td valign="top" align="center"><br><font face="Verdana" size="6"><b>Cast Away</b></font><br><br>
# 	<table border="0" cellspacing="0" cellpadding="0"><tr><td>
# ...
#
# 		</table>
#
#
#
# 		<table border="0" cellspacing="0" cellpadding="0">
# 		<tr>
# 			<td>Widest&nbsp;Release:</td>
# 			<td>&nbsp;2,587 theaters</td>
# 		</tr>
# 		</table>
#
#
#
#
# 	</div>
# </div>
# </td>
# 		<td valign="top" style="padding-left: 10px;"><div class="mp_box">
# 	<div class="mp_box_tab">The Players</div>
# 	<div class="mp_box_content">
# 	<table>
# 		</td></tr><tr><td valign="top" align="right"><font size="2"><a href="/people/?view=Director&p=.htm">Director:</font></a></td><td><font size="2"><a href="/people/chart/?view=Director&id=jameswong.htm">James Wong</a></font></td></tr><tr><td valign="top" align="right"><font size="2"><a href="/people/?view=Writer&p=.htm">Writer:</font></a></td><td><font size="2"><a href="/people/chart/?view=Writer&id=jameswong.htm">James Wong</a></font></td></tr><tr><td valign="top" align="right"><font size="2"><a href="/people/?view=Actor&p=.htm">Actors:</font></a></td><td><font size="2">Devon Sawa<br><a href="/people/chart/?view=Actor&id=alilarter.htm">Ali Larter</a></font></td></tr><tr><td valign="top" align="right"><font size="2"><a href="/people/?view=Producer&p=.htm">Producer:</font></a></td><td><font size="2"><a href="/people/chart/?view=Producer&id=chrisbender.htm">Chris Bender*</a> <font size="2">(associate)</font></font></td></tr><tr><td colspan="2" align="right"><i><small>* Denotes minor role</small></i></table></div></div></td>
# 	</tr></table>
# 		<div class="mp_box">
# 	<div class="mp_box_tab">Genres</div>
# 	<div class="mp_box_content">
# 			<table border="0" cellspacing="1" cellpadding="5" style="border-collapse: collapse" width="100%">
# 				<tr><th>Genre</th>
# 					<th>Rank</th></tr>
# <tr bgcolor="#ffffff"><td><font size="2"><a href="/genres/chart/?id=supernaturalhorror.htm">Horror - Supernatural</a></font></td>
# <td align="center"><font size="2">32</font></td>
# </tr>
#
# 					</table>
# </div></div>
#
# <div class="mp_box">
# 	<div class="mp_box_tab">Franchises</div>
# 	<div class="mp_box_content">
# 					<table border="0" cellspacing="1" cellpadding="5" style="border-collapse: collapse" width="100%">
# 						<tr><th>Franchise</th>
# 							<th>Rank</th></tr>
# <tr bgcolor="#f4f4ff"><td><font size="2"><a href="/franchises/chart/?id=finaldestination.htm"><b>Series: Final Destination</b></a></font></td>
# <td align="center"><font size="2"><b>3</b></font></td>
# </tr>
#
# <tr bgcolor="#ffffff"><td><font size="2"><a href="/showdowns/chart/?id=finaldestinationvs.htm"><b>Showdown: 'Final' Showdown</b></a></font></td>
# <td align="center"><font size="2"><b>3</b></font></td>
# </tr>
#
# </table></div></div><div class="mp_box">
# 	<div class="mp_box_tab">Charts</div>
# 	<div class="mp_box_content">
#
# 					<table border="0" cellspacing="1" cellpadding="5" style="border-collapse: collapse" width="100%">
# 						<tr><td bgcolor=><b>Chart</b></td>
# 							<td align="center"><b>Rank</b></td>
# 					</tr>
#
# <tr bgcolor="#ffffff"><td><font size="2"><a href="/alltime/domestic.htm">All Time Domestic</a></font></td>
# <td align="center"><font size="2">1,399</font></td>
# </tr>
#
# <tr bgcolor="#f4f4ff"><td><font size="2"><a href="/yearly/chart/?yr=2000&p=.htm">Yearly 2000</a></font></td>
# <td align="center"><font size="2">49</font></td>
# </tr>
#
# <tr bgcolor="#ffffff"><td><font size="2"><a href="/yearly/chart/?view2=releasedate&view=opening&yr=2000&p=.htm">Yearly Opening Weekends 2000</a></font></td>
# <td align="center"><font size="2">66</font></td>
# </tr>
#
# <tr bgcolor="#f4f4ff"><td><font size="2"><a href="/yearly/chart/mpaarating.htm?rating=R&yr=2000&p=.htm">Yearly R Rated 2000</a></font></td>
# <td align="center"><font size="2">16</font></td>
# </tr>
#
# <tr bgcolor="#ffffff"><td><font size="2"><a href="/yearly/chart/?view2=worldwide&yr=2000&p=.htm">Worldwide Yearly 2000</a></font></td>
# <td align="center"><font size="2">38</font></td>
# </tr>
#
# <tr bgcolor="#f4f4ff"><td><font size="2"><a href="/alltime/openingweeks.htm">Opening Weeks</a></font></td>
# <td align="center"><font size="2">1,871</font></td>
# </tr>
#
# <tr bgcolor="#ffffff"><td><font size="2"><a href="/alltime/weekends/">Opening Weekends</a></font></td>
# <td align="center"><font size="2">1,811</font></td>
# </tr>
#
# <tr bgcolor="#f4f4ff"><td><font size="2"><a href="/alltime/weekends/month/?mo=03&p=.htm">Opening Weekends - March</a></font></td>
# <td align="center"><font size="2">158</font></td>
# </tr>
#
# <tr bgcolor="#ffffff"><td><font size="2"><a href="/alltime/weekends/smallestdrops.htm?page=SMALLDROP25&p=.htm">Smallest Drops, 2,500+ theaters (Saturation)</a></font></td>
# <td align="center"><font size="2">159</font></td>
# </tr>
#
# <tr bgcolor="#f4f4ff"><td><font size="2"><a href="/alltime/weekends/smallestdrops.htm?page=SMALLDROP20&p=.htm">Smallest Drops, 2,000+ theaters (Very Wide)</a></font></td>
# <td align="center"><font size="2">258</font></td>
# </tr>
#
# <tr bgcolor="#ffffff"><td><font size="2"><a href="/alltime/weekends/smallestdrops.htm?page=SMALLDROPWID&p=.htm">Smallest Drops, All Wide Releases</a></font></td>
# <td align="center"><font size="2">933</font></td>
# </tr>
#
# <tr bgcolor="#f4f4ff"><td><font size="2"><a href="/grades/?page=usergrades&p=.htm">BOM Users' Grades</a></font></td>
# <td align="center"><font size="2">383</font></td>
# </tr>
#
# <tr bgcolor="#ffffff"><td><font size="2">BOM Users' Grades (2000 Releases)</font></td>
# <td align="center"><font size="2">34</font></td>
# </tr>
#
# <tr><td><b>Charts (Premier Pass Users Only)</b></td><td align="center"><b>Rank</b></td></tr><tr bgcolor="#ffffff"><td><font size="2"><a href="/alltime/domestic.htm?page=6&asof=2002-08-28&p=.htm">Highest All Time Rank (on August 28, 2002)</a></font></td>
# <td align="center"><font size="2">513</font></td>
# </tr>
#
# <tr bgcolor="#f4f4ff"><td><font size="2"><a href="/yearly/chart/?view2=wide&view=domestic&yr=2000&p=.htm">Yearly (Wide) 2000</a></font></td>
# <td align="center"><font size="2">47</font></td>
# </tr>
#
# <tr bgcolor="#ffffff"><td><font size="2"><a href="/yearly/chart/?view2=opening&yr=2000&p=.htm">Yearly Opening Weekends (Wide) 2000</a></font></td>
# <td align="center"><font size="2">66</font></td>
# </tr>
#
# <tr bgcolor="#f4f4ff"><td><font size="2"><a href="/alltime/openingweeks.htm?adjust_yr=2016&p=.htm">Opening Weeks Adjusted</a></font></td>
# <td align="center"><font size="2">1,804</font></td>
# </tr>
#
# <tr bgcolor="#ffffff"><td><font size="2"><a href="/alltime/weekends/month/?mo=03&adjust_yr=2016&p=.htm">Opening Weekends Adjusted - March</a></font></td>
# <td align="center"><font size="2">154</font></td>
# </tr>
#
# <tr bgcolor="#f4f4ff"><td><font size="2"><a href="/alltime/weekends/?adjust_yr=2016&p=.htm">Opening Weekends Adjusted</a></font></td>
# <td align="center"><font size="2">1,751</font></td>
# </tr>
#
# </table></div></div>
# 		</td>
# 	<td width="10px">&nbsp;</td>
# 	<td valign="top" width="434px">
#
# 	<div class="mp_box">
# 		<div class="mp_box_tab">Related Products</div>
# 		<div class="mp_box_content"><ul>
# <li><a href="http://www.amazon.com/gp/product/0780631684?ie=UTF8&tag=boxofficemojo-20&linkCode=as2&camp=1789&creative=9325&creativeASIN=0780631684">Final Destination</a><img src="http://www.assoc-amazon.com/e/ir?t=boxofficemojo-20&l=as2&o=1&a=0780631684" width="1" height="1" border="0" alt="" style="border:none !important; margin:0px !important;" /></li>
# <li><a href="http://www.amazon.com/gp/product/B000FBHCAK?ie=UTF8&tag=boxofficemojo-20&linkCode=as2&camp=1789&creative=9325&creativeASIN=B000FBHCAK">Final Destination Thrill-ogy</a><img src="http://www.assoc-amazon.com/e/ir?t=boxofficemojo-20&l=as2&o=1&a=B000FBHCAK" width="1" height="1" border="0" alt="" style="border:none !important; margin:0px !important;" /></li>
# <li><a href="http://www.amazon.com/gp/product/B001AQMBHI?ie=UTF8&tag=boxofficemojo-20&linkCode=as2&camp=1789&creative=9325&creativeASIN=B001AQMBHI">Final Destination</a><img src="http://www.assoc-amazon.com/e/ir?t=boxofficemojo-20&l=as2&o=1&a=B001AQMBHI" width="1" height="1" border="0" alt="" style="border:none !important; margin:0px !important;" /></li>
# <li><a href="http://www.amazon.com/gp/product/B003PIUINS?ie=UTF8&tag=boxofficemojo-20&linkCode=as2&camp=1789&creative=9325&creativeASIN=B003PIUINS">Final Destination Collection: 4 Film Favorites (Final Destination/Final Destination 2/Final Destination 3/The Final Destination)</a><img src="http://www.assoc-amazon.com/e/ir?t=boxofficemojo-20&l=as2&o=1&a=B003PIUINS" width="1" height="1" border="0" alt="" style="border:none !important; margin:0px !important;" /></li>
# </ul></div></div>	<OBJECT classid="clsid:D27CDB6E-AE6D-11cf-96B8-444553540000" codebase="http://fpdownload.macromedia.com/get/flashplayer/current/swflash.cab" id="Player_82160f42-9620-4d0a-b79a-18b1abd853fb"  WIDTH="400px" HEIGHT="150px"> <PARAM NAME="movie" VALUE="http://ws.amazon.com/widgets/q?ServiceVersion=20070822&MarketPlace=US&ID=V20070822%2FUS%2Fboxofficemojo-20%2F8010%2F82160f42-9620-4d0a-b79a-18b1abd853fb&Operation=GetDisplayTemplate"><PARAM NAME="quality" VALUE="high"><PARAM NAME="bgcolor" VALUE="#FFFFFF"><PARAM NAME="allowscriptaccess" VALUE="always"><embed src="http://ws.amazon.com/widgets/q?ServiceVersion=20070822&MarketPlace=US&ID=V20070822%2FUS%2Fboxofficemojo-20%2F8010%2F82160f42-9620-4d0a-b79a-18b1abd853fb&Operation=GetDisplayTemplate" id="Player_82160f42-9620-4d0a-b79a-18b1abd853fb" quality="high" bgcolor="#ffffff" name="Player_82160f42-9620-4d0a-b79a-18b1abd853fb" allowscriptaccess="always"  type="application/x-shockwave-flash" align="middle" height="150px" width="400px"></embed></OBJECT> <NOSCRIPT><A HREF="http://ws.amazon.com/widgets/q?ServiceVersion=20070822&MarketPlace=US&ID=V20070822%2FUS%2Fboxofficemojo-20%2F8010%2F82160f42-9620-4d0a-b79a-18b1abd853fb&Operation=NoScript">Amazon.com Widgets</A></NOSCRIPT>
#
# </td>
# </tr>
# </table>
#
# <br>
# </td>
# </tr>
# </table>
#
#
# </td></tr></table>
# 	</div>
# 	</div>
# 	<div id="hp_footer">
# 		<div style="padding-bottom: 20px;">
#
# 			<div style="margin: 0px 121px; vertical-align: top;">
# 				<div id="footer_links">
# 					<ul class="footer_link_list">
# 						<li><strong>Latest Updates</strong></li>
# 						<li><a href="/news/?ref=ft">Movie News</a>
# 						<li><a href="/daily/chart/?ref=ft">Daily Chart</a></li>
# 						<li><a href="/weekend/chart/?ref=ft">Weekend Chart</a></li>
# 						<li><a href="/alltime/?ref=ft">All Time Charts</a></li>
# 						<li><a href="/intl/?ref=ft">International Charts</a></li>
# 					</ul>
# 					<!--
# 					<ul class="footer_link_list">
# 						<li><strong>Popular Movies</strong></li>
# 											</ul>
# 					-->
# 					<ul class="footer_link_list">
# 						<li><strong>Indices</strong></li>
# 						<li><a href="/movies/?ref=ft">Movies A-Z</a></li>
# 						<li><a href="/people/?ref=ft">People</a></li>
# 						<li><a href="/genres/?ref=ft">Genres</a></li>
# 						<li><a href="/franchises/?ref=ft">Franchises</a></li>
# 						<li><a href="/showdowns/?ref=ft">Showdowns</a></li>
# 					</ul>
# 					<ul class="footer_link_list">
# 						<li><strong>Other</strong></li>
# 						<li><a href="/about/?ref=ft">About This Site</a></li>
# 						<li><a href="/about/advertise.htm?ref=ft">Advertising</a></li>
# 						<li><a href="/users/?ref=ft">My Account</a></li>
# 						<li><a href="/about/rss.htm?ref=ft">RSS Feeds</a></li>
# 					</ul>
# 				</div>
# 				<div id="copyright">
# 					<a href="/?ref=ft"><img src="/img/misc/bom_logo1.png" width="245" height="56" alt="Box Office Mojo"></a><br>
# 					<p>An <a href="http://imdb.com/"><img src="/img/misc/IMDbSm.png" width="34" height="16" alt="IMDb" valign="middle"></a> company<br><br></p>
# 					<p>&copy; <a href="http://imdb.com/">IMDb.com</a>, Inc. or its affiliates. All rights reserved. Box Office Mojo and IMDb are trademarks or registered trademarks of IMDb.com, Inc. or its affiliates. <a href="/about/termsofuse.htm">Terms of Use</a> and <a href="/about/privacy.htm">Privacy Policy</a> under which this service is provided to you.</p>
# 					</div>
# 				</div>
# 				<div style="clear:both;">
# 				<div>
# 				 <script type="text/javascript">
#     googletag.cmd.push(function() {
#         googletag.defineSlot("/4215/imdb2.bom.movie", [[728, 90]], "ad-slot-3").addService(googletag.pubads().setTargeting("p", "b"));
#         googletag.pubads().enableSingleRequest();
#         googletag.enableServices();
#     });
#     googletag.cmd.push(function() { googletag.display("ad-slot-3"); });
# </script></div>
#
# 				</div>
# 	</div>
# </div>
#
#
#
#
#
# <!-- Page generated in 0.06 seconds | . -->
# <script>
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "6034961" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#   el.parentNode.insertBefore(s, el);
#   })();
# </script>
# <noscript>
#     <img src="http://b.scorecardresearch.com/p?c1=2&c2=6034961&cv=2.0&cj=1" />
# </noscript>
# </body>
# </html>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-b49daa3af64a> in <module>()
# ----> 1 title = get_title(pages)
#
# <ipython-input-8-73085811861d> in get_title(pages)
#       2     titleList = []
#       3     for url in pages:
# ----> 4         title_string = get_soup(url).find('title').text
#       5         title = title_string.split('(')[0].strip()
#       6         titleList.append(title)
#
# <ipython-input-65-75814c9a01eb> in get_soup(url)
#       4     page = response.text
#       5     print(page)
# ----> 6     soup = BeautifulSoup(page, 'lxml')
#       7     return soup
#
# /home/patrick/anaconda3/lib/python3.5/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     213             self.reset()
#     214             try:
# --> 215                 self._feed()
#     216                 break
#     217             except ParserRejectedMarkup:
#
# /home/patrick/anaconda3/lib/python3.5/site-packages/bs4/__init__.py in _feed(self)
#     237         self.builder.reset()
#     238
# --> 239         self.builder.feed(self.markup)
#     240         # Close out any unfinished strings and close all the open tags.
#     241         self.endData()
#
# /home/patrick/anaconda3/lib/python3.5/site-packages/bs4/builder/_lxml.py in feed(self, markup)
#     238         try:
#     239             self.parser = self.parser_for(encoding)
# --> 240             self.parser.feed(markup)
#     241             self.parser.close()
#     242         except (UnicodeDecodeError, LookupError, etree.ParserError) as e:
#
# src/lxml/parser.pxi in lxml.etree._FeedParser.feed (src/lxml/lxml.etree.c:119773)()
#
# src/lxml/parser.pxi in lxml.etree._FeedParser.feed (src/lxml/lxml.etree.c:119644)()
#
# src/lxml/parsertarget.pxi in lxml.etree._TargetParserContext._handleParseResult (src/lxml/lxml.etree.c:137264)()
#
# src/lxml/parsertarget.pxi in lxml.etree._TargetParserContext._handleParseResult (src/lxml/lxml.etree.c:137128)()
#
# src/lxml/lxml.etree.pyx in lxml.etree._ExceptionContext._raise_if_stored (src/lxml/lxml.etree.c:11090)()
#
# src/lxml/saxparser.pxi in lxml.etree._handleSaxTargetStartNoNs (src/lxml/lxml.etree.c:129328)()
#
# src/lxml/saxparser.pxi in lxml.etree._callTargetSaxStart (src/lxml/lxml.etree.c:129536)()
#
# src/lxml/parsertarget.pxi in lxml.etree._PythonSaxParserTarget._handleSaxStart (src/lxml/lxml.etree.c:136179)()
#
# /home/patrick/anaconda3/lib/python3.5/site-packages/bs4/builder/_lxml.py in start(self, name, attrs, nsmap)
#     172         namespace, name = self._getNsTag(name)
#     173         nsprefix = self._prefix_for_namespace(namespace)
# --> 174         self.soup.handle_starttag(name, namespace, nsprefix, attrs)
#     175
#     176     def _prefix_for_namespace(self, namespace):
#
# /home/patrick/anaconda3/lib/python3.5/site-packages/bs4/__init__.py in handle_starttag(self, name, namespace, nsprefix, attrs)
#     402
#     403         tag = Tag(self, self.builder, name, namespace, nsprefix, attrs,
# --> 404                   self.currentTag, self._most_recent_element)
#     405         if tag is None:
#     406             return tag
#
# KeyboardInterrupt:

# %% [markdown]
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^

# %%
N = 1600 #number of observations
N = N + 1
d = data_series(rawdict, title, N)
df = pd.DataFrame(d)
df = df[['Rank', 'title','Domestic Total Gross','Release Date', 'Runtime', 'Rating']]

# %%
# %matplotlib inline
#from matplotlib import pyplot as pt
import matplotlib as mpl
import matplotlib.pyplot as plt

matplotlib.style.use('ggplot')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-f02fc128ab23> in <module>()
#       4 import matplotlib.pyplot as plt
#       5
# ----> 6 matplotlib.style.use('ggplot')
#
# NameError: name 'matplotlib' is not defined

# %% [markdown]
# ## Challenge 1

# %%
styles = ['b^-']
linewidths = [2, 1]
fig, ax = plt.subplots()
for col, style, lw in zip(df, styles, linewidths):
    df.plot(x = 'Release Date', y = 'Domestic Total Gross', style=style, lw=lw, ax=ax,figsize=(15, 10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-c84779457b0a> in <module>()
#       1 styles = ['b^-']
#       2 linewidths = [2, 1]
# ----> 3 fig, ax = plt.subplots()
#       4 for col, style, lw in zip(df, styles, linewidths):
#       5     df.plot(x = 'Release Date', y = 'Domestic Total Gross', style=style, lw=lw, ax=ax,figsize=(15, 10))
#
# NameError: name 'plt' is not defined

# %%
df.plot(x = 'Release Date', y = 'Domestic Total Gross',figsize=(15, 10))

# %% [markdown]
# ## Challenge 2

# %%
df2=df.groupby(['Rating'])
df2

# %%
df.sort_values('Runtime', ascending=True).plot(kind='scatter',
                                               title = 'Total Gross vs Runtime of top 100 movies from each year (2000 - 2015)',
                                               x = 'Runtime', y = 'Domestic Total Gross', s=200,
                                               color ='darkblue',
                                               figsize = (15,10),
                                               )

# %% [markdown]
# ## Challenge 3

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
df1 = df.sort_values(by=['Rating'], ascending = False).groupby("Rating")
print(df1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bae6c9926a7f> in <module>()
# ----> 1 pd.set_option('display.float_format', lambda x: '%.3f' % x)
#       2 df1 = df.sort_values(by=['Rating'], ascending = False).groupby("Rating")
#       3 print(df1)
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ## Challenge 4
# #### Make one figure with (N=the number of MPAA ratings there are) subplots, and in each plot the release date vs the domestic total gross.

# %%
df1 = df.groupby("Rating", as_index=False)

# for rating in df1['Rating']:
#     df1.plot(x = 'Runtime', y = 'Domestic Total Gross',        
#              figsize=(15, 10),
#             legend = False)
# Out:
# <pandas.core.groupby.DataFrameGroupBy object at 0x7fd0f16935c0>

# %% [markdown]
# ## Challenge 5
#
# What director in your dataset has the highest gross per movie?
