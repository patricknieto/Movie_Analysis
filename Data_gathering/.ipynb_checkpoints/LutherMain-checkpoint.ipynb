# %%
import urllib 
from bs4 import BeautifulSoup  
import logging  
from urllib.request import urlopen
import requests
import re
import pandas as pd
from collections import defaultdict
import pickle
import numpy as np
import pandas as pd
import dateutil.parser
from datetime import timedelta

# %%
def main():
    #create a list of page links to the yearly charts. Number of charts set in get_pages()
    movie_page = []
    for url in get_pages():
        #get soup result from every chart in order to find all of the movie links
        soup_result = get_soup(url)
        #loop through every link on chart pages and add them too a larger list of all movie links
        for link in generate_links(soup_result):
            movie_page.append(link)
    #Retrieve all necessary info from each page link and save it as a list of dictionaries.
    amd = getAllMovieData(movie_page)

# %%
def get_soup(url):
    try:
        response = requests.get(url)
        page = response.text
        soup = BeautifulSoup(page, 'lxml')

    except requests.ConnectionError:
        print("failed to connect")

    return soup

# %%
def get_pages ():
    
    url_list =[]
    for year in range(0,10):
        for page in range(1,3):
            url = 'http://www.boxofficemojo.com/yearly/chart/?page=' + str(page) +'&view=releasedate&view2=domestic&yr=200' + str(year) + '&p=.htm'
            url_list.append(url)
    for year in range(10,16):
        for page in range(1,3):
            url = 'http://www.boxofficemojo.com/yearly/chart/?page=' + str(page) +'&view=releasedate&view2=domestic&yr=20' + str(year) + '&p=.htm'
            url_list.append(url)

    
    return url_list

# %%
def generate_links(soup):

    my_list = []
    for link in soup.find("body").find_all('a', href=True):
        if link['href'].startswith('/movies/?id='):
            my_list.append('http://www.boxofficemojo.com' + link['href'])
        elif link['href'] == '' or link['href'].startswith('#'):
            continue
    link_list = (my_list[1:])
    return(link_list)

# %%
def get_actor_listlinks(movie_page):
    actorlist = []
    for url in movie_page[:10]:
        temp_list = []
        obj = get_soup(url).find(text=re.compile('Actor'))
        for link in obj.findNext('td').find_all('a', href=True):
            temp_list.append('http://www.boxofficemojo.com' + link['href'])
        actorlist.append(temp_list)
    return(actorlist)

# %%
def get_actor_list(soup):
    actornames = []
    actorElapsedTimes = []
    actordict = defaultdict(list)
    obj = soup.find(text=re.compile('Actor'))
    if not obj: 
        return None
    else:
        for link in obj.findNext('td').find_all('a'):
            actornames.append(link.text)
            actornames.append(get_actor_date_diff(link['href']))
    
#     obj = soup.find(text=re.compile('Actor'))
#     for link in obj.findNext('td').find_all('a'):
#         actorElapsedTimes.append(link['href'])  
    actordict = dict(actornames[i:i+2] for i in range(0, len(actornames), 2))
    return(actordict)

# %%
def get_actor_date_diff(href):
    temp_list = []
    days_passed = []
    href = 'http://www.boxofficemojo.com/'+ href
    for link in get_soup(href).find_all('a', href=True):
        if link['href'].startswith('/schedule/?view=bydate&release=theatrical&date='):
            temp_list.append(to_date(link.text))
    days_passed.append(temp_list[1] - temp_list[0])
    return(days_passed)

# %%
def to_date(datestring):
    date = dateutil.parser.parse(datestring)
    return date

def money_to_int(moneystring):
    moneystring = moneystring.replace(' (Estimate)', '')
    moneystring = moneystring.replace('$', '').replace(',', '')
    return int(moneystring)

def runtime_to_minutes(runtimestring):
    runtime = runtimestring.split()
    try:
        minutes = int(runtime[0])*60 + int(runtime[2])
        return minutes
    except:
        return None

def get_movie_value(soup, field_name):
    '''Grab a value from boxofficemojo HTML
    
    Takes a string attribute of a movie on the page and
    returns the string in the next sibling object
    (the value for that attribute)
    or None if nothing is found.
    '''
    obj = soup.find(text=re.compile(field_name))
    if not obj: 
        return None
    in_box_content = obj.find_parents(class_='mp_box_content')
    if in_box_content:
        return getBoxContent(obj)
    else:
        return getHeadTableContent(obj)
    

def getHeadTableContent(obj):
    next_sibling = obj.findNextSibling()
    parent_sibling = obj.find_parent().findNextSibling()
    if next_sibling:
        return next_sibling.text 
    elif parent_sibling:
        return parent_sibling.text
    else:
        return None
    
def getBoxContent(obj):
    
    other = obj.find_parent('td').find_next_sibling('td')
    
    if not other:
        return None
    else:
        return other.get_text(strip=True)
    
def getSingleMovieData(url):
    #create a blank dictionary that will be used to track the movie data
    movie_data = {}
    
    #get the raw movie HTML and create a BeautifulSoup object with the text
    soup = get_soup(url)
    
    movie_data['url'] = url
    
    #get the movie director and add it to `movie_data` dictionary
    movie_data['director'] = get_movie_value(soup, 'Director')

    #get the movie title
    title_string = soup.find('title').text
    title = title_string.split('(')[0].strip()
    movie_data['title'] = title
    
    #get the release date
    raw_release_date = get_movie_value(soup,'Release Date')
    movie_data['release_date'] = to_date(raw_release_date)
    
    #get the domestic total gross
    raw_domestic_total_gross = get_movie_value(soup,'Domestic Total')
    movie_data['domestic_total_gross'] = money_to_int(raw_domestic_total_gross)
    
    #get the MPAA rating
    movie_data['rating'] = get_movie_value(soup,'MPAA Rating')
    
    raw_runtime = get_movie_value(soup,'Runtime')
    movie_data['runtime'] = runtime_to_minutes(raw_runtime)
    
    movie_data['actors'] = get_actor_list(soup)
    
    actordict = get_actor_list(soup)
    movie_data['avg time passed']  =  actordict
    
    return movie_data

# %%
def getAllMovieData(movie_pages):
    data = []
    count = 0
    for i in movie_pages:
        movie_data = getSingleMovieData(i)
        data.append(movie_data)
        count += 1
        print(count)
    return data

# %%
main()

# %%
with open('MovieDict.pickle', 'rb') as handle:
  b = pickle.load(handle)

# %%
df = pd.DataFrame(b)

# %%
df.head()
# Out:
#                                               actors         director  \
# 0  {'Jim Carrey': [-455 days, 0:00:00], 'Anthony ...       Ron Howard
# 1  {'Tom Hanks': [-672 days, 0:00:00], 'Helen Hun...  Robert Zemeckis
# 2  {'Tom Cruise': [-420 days, 0:00:00], 'Brendan ...         John Woo
# 3  {'Joaquin Phoenix': [-217 days, 0:00:00], 'Rus...     Ridley Scott
# 4  {'Logan Lerman*': [-203 days, 0:00:00], 'Helen...     Nancy Meyers
#
#    domestic_total_gross rating release_date  runtime  \
# 0             260044825     PG   2000-11-17      104
# 1             233632142  PG-13   2000-12-22      143
# 2             215409889  PG-13   2000-05-24      123
# 3             187705427      R   2000-05-05      155
# 4             182811707  PG-13   2000-12-15      127
#
#                             title  \
# 0  How the Grinch Stole Christmas
# 1                       Cast Away
# 2          Mission: Impossible II
# 3                       Gladiator
# 4                 What Women Want
#
#                                                  url
# 0  http://www.boxofficemojo.com/movies/?id=grinch...
# 1  http://www.boxofficemojo.com/movies/?id=castaw...
# 2    http://www.boxofficemojo.com/movies/?id=mi2.htm
# 3  http://www.boxofficemojo.com/movies/?id=gladia...
# 4  http://www.boxofficemojo.com/movies/?id=whatwo...

# %%
avgDays = []
numActors = []
actors2 = []
for a in df['actor data']:
    if a:
        avgDays.append(np.mean([v for k,v in a.items() if v != None]))
        numActors.append(len(a))
        actors2.append([k for k,v in a.items() if v != None])
    else:
        avgDays.append(None)
        numActors.append(None)
        actors2.append(None)
len(avgDays)
df['actors'] = actors2
df['number of actors'] = numActors
df['avg of actors\' days since last movie'] = [abs((np.timedelta64(day) / np.timedelta64(1, 'D')) - 1).astype(int) if day else None for day in avgDays]

# %%
df.drop('actors2', axis=1, inplace=True)

# %%
df.head(43)
# Out:
#                director  domestic_total_gross rating release_date  runtime  \
# 0            Ron Howard             260044825     PG   2000-11-17      104
# 1       Robert Zemeckis             233632142  PG-13   2000-12-22      143
# 2              John Woo             215409889  PG-13   2000-05-24      123
# 3          Ridley Scott             187705427      R   2000-05-05      155
# 4          Nancy Meyers             182811707  PG-13   2000-12-15      127
# 5     Wolfgang Petersen             182618434  PG-13   2000-06-30      129
# 6             Jay Roach             166244045  PG-13   2000-10-06      108
# 7          Bryan Singer             157299717  PG-13   2000-07-14      104
# 8   Keenen Ivory Wayans             157019771      R   2000-07-07       88
# 9       Robert Zemeckis             155464351  PG-13   2000-07-21      130
# 10                 None             137748063     PG   2000-05-19       82
# 11              Ang Lee             128078872  PG-13   2000-12-08      120
# 12    Steven Soderbergh             125595205      R   2000-03-17      130
# 13                  McG             125305545  PG-13   2000-11-03       98
# 14    Steven Soderbergh             124115725      R   2000-12-27      147
# 15          Peter Segal             123309890  PG-13   2000-07-28      106
# 16         Raja Gosnell             117559438  PG-13   2000-06-02       98
# 17           Boaz Yakin             115654751     PG   2000-09-29      113
# 18      Roland Emmerich             113330342      R   2000-06-28      164
# 19           Peter Lord             106834564      G   2000-06-23       84
# 20                 None             106807667  PG-13   2000-12-22      109
# 21         Dominic Sena             101648571  PG-13   2000-06-09      117
# 22   M. Night Shyamalan              95011339  PG-13   2000-11-22      106
# 23   The Farrelly Bros.              90570999      R   2000-06-23      116
# 24       Clint Eastwood              90464773  PG-13   2000-08-04      130
# 25                 None              89302687      G   2000-12-15       78
# 26           Wes Craven              89143175      R   2000-02-04      117
# 27                 None              77122415  PG-13   2000-04-21      117
# 28                 None              76507756      G   2000-11-17       78
# 29         Brett Ratner              75793305  PG-13   2000-12-22      126
# 30       Paul Verhoeven              73209340      R   2000-08-04      113
# 31      Lasse Hallstrom              71509363  PG-13   2000-12-15      105
# 32       John Singleton              70334258      R   2000-06-16      127
# 33       Jon Turteltaub              69691949     PG   2000-07-07      104
# 34      Martin Campbell              69243859  PG-13   2000-12-08      124
# 35        Todd Phillips              68540777      R   2000-05-19       94
# 36          Peyton Reed              68379000  PG-13   2000-08-25       98
# 37                 None              66957026      G   2000-11-22      104
# 38     William Friedkin              61335230      R   2000-04-07      127
# 39               Tarsem              61334059      R   2000-08-18      107
# 40       Brian De Palma              60883407     PG   2000-03-10      113
# 41                 None              60786269  PG-13   2000-08-04      101
# 42                 None              60655420      G   2000-01-01       75
#
#                                  title  \
# 0       How the Grinch Stole Christmas
# 1                            Cast Away
# 2               Mission: Impossible II
# 3                            Gladiator
# 4                      What Women Want
# 5                    The Perfect Storm
# 6                     Meet the Parents
# 7                                X-Men
# 8                          Scary Movie
# 9                    What Lies Beneath
# 10                            Dinosaur
# 11      Crouching Tiger, Hidden Dragon
# 12                     Erin Brockovich
# 13                    Charlie's Angels
# 14                             Traffic
# 15  The Nutty Professor II: The Klumps
# 16                   Big Momma's House
# 17                 Remember the Titans
# 18                         The Patriot
# 19                         Chicken Run
# 20                   Miss Congeniality
# 21                  Gone in 60 Seconds
# 22                         Unbreakable
# 23                Me, Myself and Irene
# 24                       Space Cowboys
# 25            The Emperor's New Groove
# 26                            Scream 3
# 27                               U-571
# 28         Rugrats in Paris: The Movie
# 29                      The Family Man
# 30                          Hollow Man
# 31                            Chocolat
# 32                               Shaft
# 33                    Disney's The Kid
# 34                      Vertical Limit
# 35                           Road Trip
# 36                         Bring It On
# 37                      102 Dalmatians
# 38                 Rules of Engagement
# 39                            The Cell
# 40                     Mission to Mars
# 41                         Coyote Ugly
# 42                       Fantasia 2000
#
#                                                   url  \
# 0   http://www.boxofficemojo.com/movies/?id=grinch...
# 1   http://www.boxofficemojo.com/movies/?id=castaw...
# 2     http://www.boxofficemojo.com/movies/?id=mi2.htm
# 3   http://www.boxofficemojo.com/movies/?id=gladia...
# 4   http://www.boxofficemojo.com/movies/?id=whatwo...
# 5   http://www.boxofficemojo.com/movies/?id=perfec...
# 6   http://www.boxofficemojo.com/movies/?id=meetth...
# 7    http://www.boxofficemojo.com/movies/?id=xmen.htm
# 8   http://www.boxofficemojo.com/movies/?id=scarym...
# 9   http://www.boxofficemojo.com/movies/?id=whatli...
# 10  http://www.boxofficemojo.com/movies/?id=dinosa...
# 11  http://www.boxofficemojo.com/movies/?id=crouch...
# 12  http://www.boxofficemojo.com/movies/?id=erinbr...
# 13  http://www.boxofficemojo.com/movies/?id=charli...
# 14  http://www.boxofficemojo.com/movies/?id=traffi...
# 15  http://www.boxofficemojo.com/movies/?id=nuttyp...
# 16  http://www.boxofficemojo.com/movies/?id=bigmom...
# 17  http://www.boxofficemojo.com/movies/?id=rememb...
# 18  http://www.boxofficemojo.com/movies/?id=patrio...
# 19  http://www.boxofficemojo.com/movies/?id=chicke...
# 20  http://www.boxofficemojo.com/movies/?id=missco...
# 21  http://www.boxofficemojo.com/movies/?id=gonein...
# 22  http://www.boxofficemojo.com/movies/?id=unbrea...
# 23  http://www.boxofficemojo.com/movies/?id=memyse...
# 24  http://www.boxofficemojo.com/movies/?id=spacec...
# 25  http://www.boxofficemojo.com/movies/?id=empero...
# 26  http://www.boxofficemojo.com/movies/?id=scream...
# 27  http://www.boxofficemojo.com/movies/?id=u-571.htm
# 28  http://www.boxofficemojo.com/movies/?id=rugrat...
# 29  http://www.boxofficemojo.com/movies/?id=family...
# 30  http://www.boxofficemojo.com/movies/?id=hollow...
# 31  http://www.boxofficemojo.com/movies/?id=chocol...
# 32  http://www.boxofficemojo.com/movies/?id=shaft.htm
# 33  http://www.boxofficemojo.com/movies/?id=kidthe...
# 34  http://www.boxofficemojo.com/movies/?id=vertic...
# 35  http://www.boxofficemojo.com/movies/?id=roadtr...
# 36  http://www.boxofficemojo.com/movies/?id=bringi...
# 37  http://www.boxofficemojo.com/movies/?id=102dal...
# 38  http://www.boxofficemojo.com/movies/?id=ruleso...
# 39   http://www.boxofficemojo.com/movies/?id=cell.htm
# 40  http://www.boxofficemojo.com/movies/?id=missio...
# 41  http://www.boxofficemojo.com/movies/?id=coyote...
# 42  http://www.boxofficemojo.com/movies/?id=fantas...
#
#     avg of actors' days since last movie  number of actors  \
# 0                                    298                 2
# 1                                    799                 2
# 2                                    356                 4
# 3                                    305                 2
# 4                                    422                 6
# 5                                    194                 3
# 6                                    174                 3
# 7                                    500                 8
# 8                                    567                 5
# 9                                    340                 2
# 10                                   169                 1
# 11                                   288                 1
# 12                                   403                 2
# 13                                   526                 8
# 14                                   282                10
# 15                                   127                 1
# 16                                   243                 5
# 17                                   382                 4
# 18                                   436                 4
# 19                                   214                 2
# 20                                    65                 3
# 21                                   275                 5
# 22                                    39                 3
# 23                                   806                 4
# 24                                   800                 4
# 25                                   806                 1
# 26                                  1435                 6
# 27                                   316                 1
# 28                                   400                 1
# 29                                   551                 3
# 30                                    92                 2
# 31                                   328                 4
# 32                                   105                 5
# 33                                   416                 3
# 34                                   358                 1
# 35                                  2533                 1
# 36                                   540                 1
# 37                                    95                 2
# 38                                   256                 4
# 39                                   204                 3
# 40                                   298                 2
# 41                                   744                 4
# 42                                   NaN               NaN
#
#                                            actor data  \
# 0   {'Jim Carrey': [-455 days, 0:00:00], 'Anthony ...
# 1   {'Tom Hanks': [-672 days, 0:00:00], 'Helen Hun...
# 2   {'Tom Cruise': [-420 days, 0:00:00], 'Brendan ...
# 3   {'Joaquin Phoenix': [-217 days, 0:00:00], 'Rus...
# 4   {'Logan Lerman*': [-203 days, 0:00:00], 'Helen...
# 5   {'Mark Wahlberg': [-182 days, 0:00:00], 'Diane...
# 6   {'Ben Stiller': [-322 days, 0:00:00], 'Robert ...
# 7   {'Anna Paquin': [-1517 days, 0:00:00], 'Patric...
# 8   {'Shawn Wayans': [-751 days, 0:00:00], 'Anna F...
# 9   {'Michelle Pfeiffer': [-441 days, 0:00:00], 'H...
# 10       {'Hayden Panettiere*': [-168 days, 0:00:00]}
# 11               {'Zhang Ziyi': [-287 days, 0:00:00]}
# 12  {'Julia Roberts': [-693 days, 0:00:00], 'Aaron...
# 13  {'Bill Murray': [-175 days, 0:00:00], 'Luke Wi...
# 14  {'John Slattery*': [-112 days, 0:00:00], 'Erik...
# 15             {'Eddie Murphy': [-126 days, 0:00:00]}
# 16  {'Cedric the Entertainer*': [-490 days, 0:00:0...
# 17  {'Hayden Panettiere': [-168 days, 0:00:00], 'R...
# 18  {'Logan Lerman*': [-203 days, 0:00:00], 'Mel G...
# 19  {'Imelda Staunton*': [-119 days, 0:00:00], 'Me...
# 20  {'Michael Caine': [-42 days, 0:00:00], 'Sandra...
# 21  {'Timothy Olyphant': [-434 days, 0:00:00], 'Gi...
# 22  {'M. Night Shyamalan*': None, 'Samuel L. Jacks...
# 23  {'Jim Carrey': [-455 days, 0:00:00], 'Renee Ze...
# 24  {'Clint Eastwood': [-1379 days, 0:00:00], 'Jam...
# 25             {'David Spade*': [-805 days, 0:00:00]}
# 26  {'Courteney Cox': [-841 days, 0:00:00], 'Neve ...
# 27      {'Matthew McConaughey': [-315 days, 0:00:00]}
# 28          {'Susan Sarandon*': [-399 days, 0:00:00]}
# 29  {'Don Cheadle': [-336 days, 0:00:00], 'Nicolas...
# 30  {'Josh Brolin': [-140 days, 0:00:00], 'Kevin B...
# 31  {'Alfred Molina': [-210 days, 0:00:00], 'Judi ...
# 32  {'Jeffrey Wright': [-369 days, 0:00:00], 'Chri...
# 33  {'Melissa McCarthy*': [-308 days, 0:00:00], 'L...
# 34          {'Chris O'Donnell': [-357 days, 0:00:00]}
# 35           {'Breckin Meyer': [-2532 days, 0:00:00]}
# 36            {'Kirsten Dunst': [-539 days, 0:00:00]}
# 37  {'Ioan Gruffudd': [-105 days, 0:00:00], 'Glenn...
# 38  {'Tommy Lee Jones': [-518 days, 0:00:00], 'Guy...
# 39  {'Vince Vaughn': [-469 days, 0:00:00], 'Peter ...
# 40  {'Don Cheadle': [-336 days, 0:00:00], 'Tim Rob...
# 41  {'Maria Bello': [-245 days, 0:00:00], 'Johnny ...
# 42                                               None
#
#                                                actors
# 0                      [Jim Carrey, Anthony Hopkins*]
# 1                             [Tom Hanks, Helen Hunt]
# 2   [Tom Cruise, Brendan Gleeson, Anthony Hopkins,...
# 3                    [Joaquin Phoenix, Russell Crowe]
# 4   [Logan Lerman*, Helen Hunt, Alan Alda, Mel Gib...
# 5         [Mark Wahlberg, Diane Lane, George Clooney]
# 6          [Ben Stiller, Robert DeNiro, Owen Wilson*]
# 7   [Anna Paquin, Patrick Stewart, Ian McKellen, R...
# 8   [Shawn Wayans, Anna Faris, Marlon Wayans, Regi...
# 9                  [Michelle Pfeiffer, Harrison Ford]
# 10                               [Hayden Panettiere*]
# 11                                       [Zhang Ziyi]
# 12                     [Julia Roberts, Aaron Eckhart]
# 13  [Bill Murray, Luke Wilson*, Sam Rockwell, Lucy...
# 14  [John Slattery*, Erika Christensen*, Dennis Qu...
# 15                                     [Eddie Murphy]
# 16  [Cedric the Entertainer*, Nia Long, Paul Giama...
# 17  [Hayden Panettiere, Ryan Gosling*, Denzel Wash...
# 18  [Logan Lerman*, Mel Gibson, Heath Ledger, Chri...
# 19                     [Imelda Staunton*, Mel Gibson]
# 20    [Michael Caine, Sandra Bullock, Benjamin Bratt]
# 21  [Timothy Olyphant, Giovanni Ribisi, Nicolas Ca...
# 22                  [Samuel L. Jackson, Bruce Willis]
# 23  [Jim Carrey, Renee Zellweger, Tony Cox, Chris ...
# 24  [Clint Eastwood, James Garner, Tommy Lee Jones...
# 25                                     [David Spade*]
# 26  [Courteney Cox, Neve Campbell, Lance Henriksen...
# 27                              [Matthew McConaughey]
# 28                                  [Susan Sarandon*]
# 29             [Don Cheadle, Nicolas Cage, Tea Leoni]
# 30                         [Josh Brolin, Kevin Bacon]
# 31  [Alfred Molina, Judi Dench, Carrie-Anne Moss, ...
# 32  [Jeffrey Wright, Christian Bale, Toni Collette...
# 33     [Melissa McCarthy*, Lily Tomlin, Bruce Willis]
# 34                                  [Chris O'Donnell]
# 35                                    [Breckin Meyer]
# 36                                    [Kirsten Dunst]
# 37                       [Ioan Gruffudd, Glenn Close]
# 38  [Tommy Lee Jones, Guy Pearce, Ben Kingsley, Sa...
# 39   [Vince Vaughn, Peter Sarsgaard*, Jennifer Lopez]
# 40                         [Don Cheadle, Tim Robbins]
# 41  [Maria Bello, Johnny Knoxville*, Bridget Moyna...
# 42                                               None

# %% [markdown]
# ## Plots

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import gaussian_kde

# %%
fig, axScatter = plt.subplots(figsize=(12, 10))
df['days_passed_square_root'] = df['avg of actors\' days since last movie']**(1/2)
plt.scatter(df['runtime'], df['avg of actors\' days since last movie'])

# %%
xs = np.linspace(0,2000,3200)
density_1 = gaussian_kde(df['Avg. Days Passed since Last Movie'].dropna())
density_1.covariance_factor = lambda : .25
density_1._compute_covariance()
plt.figure(figsize = (20,8))
plt.plot(xs,density_1(xs))
plt.fill(xs,density_1(xs),'b',alpha=0.1)
plt.xlabel('x',fontsize=30)    #add an x label
plt.ylabel('density of y',fontsize=30)    #add a y label
plt.text(np.mean(df['Avg. Days Passed since Last Movie'].dropna()),max(density_1(xs))/2.0,r'$\widehat{x}_1$',fontsize=30)

# %%
fig, axScatter = plt.subplots(figsize=(12, 10))
plt.scatter(df['domestic_total_gross'], df['avg of actors\' days since last movie'])
plt.title('Box Office Gross predicted by Avg. Days Passed since Last Movie', fontsize=16)
plt.ylabel('Domestic Gross', fontsize=12)
plt.xlabel('Avg of Actors\' days since last movie',fontsize=12)
plt.grid(True)

# %%
plt.scatter(df['domestic_total_gross'], df['number of actors'])

# %%
plt.scatter(df['domestic_total_gross'], df['runtime'])

# %% [markdown]
# ## Models

# %%
df.head()
# Out:
#           director  domestic_total_gross rating release_date  runtime  \
# 0       Ron Howard             260044825     PG   2000-11-17      104
# 1  Robert Zemeckis             233632142  PG-13   2000-12-22      143
# 2         John Woo             215409889  PG-13   2000-05-24      123
# 3     Ridley Scott             187705427      R   2000-05-05      155
# 4     Nancy Meyers             182811707  PG-13   2000-12-15      127
#
#                             title  \
# 0  How the Grinch Stole Christmas
# 1                       Cast Away
# 2          Mission: Impossible II
# 3                       Gladiator
# 4                 What Women Want
#
#                                                  url  \
# 0  http://www.boxofficemojo.com/movies/?id=grinch...
# 1  http://www.boxofficemojo.com/movies/?id=castaw...
# 2    http://www.boxofficemojo.com/movies/?id=mi2.htm
# 3  http://www.boxofficemojo.com/movies/?id=gladia...
# 4  http://www.boxofficemojo.com/movies/?id=whatwo...
#
#    avg of actors' days since last movie  number of actors  \
# 0                                   298                 2
# 1                                   799                 2
# 2                                   356                 4
# 3                                   305                 2
# 4                                   422                 6
#
#                                           actor data  \
# 0  {'Jim Carrey': [-455 days, 0:00:00], 'Anthony ...
# 1  {'Tom Hanks': [-672 days, 0:00:00], 'Helen Hun...
# 2  {'Tom Cruise': [-420 days, 0:00:00], 'Brendan ...
# 3  {'Joaquin Phoenix': [-217 days, 0:00:00], 'Rus...
# 4  {'Logan Lerman*': [-203 days, 0:00:00], 'Helen...
#
#                                               actors  days_passed_squared  \
# 0                     [Jim Carrey, Anthony Hopkins*]            17.262677
# 1                            [Tom Hanks, Helen Hunt]            28.266588
# 2  [Tom Cruise, Brendan Gleeson, Anthony Hopkins,...            18.867962
# 3                   [Joaquin Phoenix, Russell Crowe]            17.464249
# 4  [Logan Lerman*, Helen Hunt, Alan Alda, Mel Gib...            20.542639
#
#    days_passed_square_root
# 0                17.262677
# 1                28.266588
# 2                18.867962
# 3                17.464249
# 4                20.542639

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.cross_validation import KFold, train_test_split
from patsy import dmatrices, dmatrix
import statsmodels.api as sm
from statsmodels.tools.eval_measures import mse
from sklearn.metrics import r2_score
from scipy.stats import linregress
from pylab import plot,show,hist

# %%
data = df.ix[:, (1,4,5,7,8)]
dataNoNan = data.dropna()

# %%
y = dataNoNan['domestic_total_gross']
X = dataNoNan.drop(['domestic_total_gross', 'title'], 1)

# %%
ones = np.ones(3199)
X['intercept'] = [1.0]*X.shape[0]

# %%
X.head()
# Out:
#    runtime  avg of actors' days since last movie  number of actors  intercept
# 0      104                                   298                 2          1
# 1      143                                   799                 2          1
# 2      123                                   356                 4          1
# 3      155                                   305                 2          1
# 4      127                                   422                 6          1

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.25)

# %%
model = sm.OLS(y_train, X_train)
results = model.fit()

# %%
results = model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     domestic_total_gross   R-squared:                       0.214
# Model:                              OLS   Adj. R-squared:                  0.213
# Method:                   Least Squares   F-statistic:                     173.6
# Date:                  Mon, 18 Apr 2016   Prob (F-statistic):           1.54e-99
# Time:                          17:10:00   Log-Likelihood:                -37176.
# No. Observations:                  1913   AIC:                         7.436e+04
# Df Residuals:                      1909   BIC:                         7.438e+04
# Df Model:                             3
# Covariance Type:              nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------------------------
# runtime                               7.659e+05   8.83e+04      8.674      0.000      5.93e+05  9.39e+05
# avg of actors' days since last movie   1.89e+04   4909.168      3.849      0.000      9267.811  2.85e+04
# number of actors                      1.306e+07   7.47e+05     17.490      0.000      1.16e+07  1.45e+07
# intercept                            -7.653e+07   9.51e+06     -8.044      0.000     -9.52e+07 -5.79e+07
# ==============================================================================
# Omnibus:                     1264.685   Durbin-Watson:                   2.054
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            25409.820
# Skew:                           2.797   Prob(JB):                         0.00
# Kurtosis:                      19.955   Cond. No.                     3.00e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  3e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
y_predictTest = results.predict(X_test)

# %%
mse1  = mse(y_test, y_predictTest,  axis=0)
mse1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-444-70f87dff1c9b> in <module>()
# ----> 1 mse1  = mse(y_test, y_predictTest,  axis=0)
#       2 mse1
#
# TypeError: 'numpy.float64' object is not callable

# %%
rSquared = r2_score(y_test, y_predictTest)
rSquared
# Out:
# 0.16173871170849186

# %%
rSqAdj = 1-(1-rSquared)*((len(y_test)-1)/(len(y_test)-len(X_test.columns)))
rSqAdj
# Out:
# 0.15777217564402102
