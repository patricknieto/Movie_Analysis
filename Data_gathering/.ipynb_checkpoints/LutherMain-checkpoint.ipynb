# %%
import urllib 
from bs4 import BeautifulSoup  
import logging  
from urllib.request import urlopen
import requests
import re
import pandas as pd
from collections import defaultdict
import pickle
import numpy as np
import pandas as pd
import dateutil.parser
from datetime import timedelta

# %%
with open('MovieDict.pickle', 'rb') as handle:
  b = pickle.load(handle)

# %%
df1 = pd.DataFrame(b)

# %%
len(df)
# Out:
# 500

# %%
[k for k,v in df1['directors'][0].items()]
# Out:
# ['Ron Howard']

# %%
len(df1['directors'])
# Out:
# 500

# %%
df1.head()
# Out:
#                                               actors  \
# 0  {'Jim Carrey': ([-455 days, 0:00:00], '0', 196...
# 1  {'Helen Hunt': ([-924 days, 0:00:00], '1', 196...
# 2  {'Thandie Newton': ([-812 days, 0:00:00], '1',...
# 3  {'Joaquin Phoenix': ([-217 days, 0:00:00], '0'...
# 4  {'Helen Hunt': ([-924 days, 0:00:00], '1', 196...
#
#                                            directors  domestic_total_gross  \
# 0  {'Ron Howard': ([-812 days, 0:00:00], '0', 195...             260044825
# 1  {'Robert Zemeckis': ([-1062 days, 0:00:00], No...             233632142
# 2  {'John Woo': ([-2155 days, 0:00:00], None, 194...             215409889
# 3  {'Ridley Scott': ([-294 days, 0:00:00], None, ...             187705427
# 4  {'Nancy Meyers': ([-2100 days, 0:00:00], None,...             182811707
#
#    production rating release_date  runtime                           title  \
# 0   123000000     PG   2000-11-17      104  How the Grinch Stole Christmas
# 1    90000000  PG-13   2000-12-22      143                       Cast Away
# 2   125000000  PG-13   2000-05-24      123          Mission: Impossible II
# 3   103000000      R   2000-05-05      155                       Gladiator
# 4    70000000  PG-13   2000-12-15      127                 What Women Want
#
#                                                  url
# 0  http://www.boxofficemojo.com/movies/?id=grinch...
# 1  http://www.boxofficemojo.com/movies/?id=castaw...
# 2    http://www.boxofficemojo.com/movies/?id=mi2.htm
# 3  http://www.boxofficemojo.com/movies/?id=gladia...
# 4  http://www.boxofficemojo.com/movies/?id=whatwo...

# %%
actors = df1['directors'][i]
actors
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-661-425b784e9108> in <module>()
# ----> 1 actors = df1['directors'][i].keys()[0]
#       2 actors
#
# TypeError: 'dict_keys' object does not support indexing

# %%
data1 = pd.DataFrame()
for i in range(0, len(df1['directors'])):
    directors = pd.DataFrame(df1['directors'][i])
    directors=directors.T
    directors['title']=df1['title'][i]
    directors['Domestic'] = df1['domestic_total_gross'][i]
    directors['production'] = df1['production'][i]
    directors['runtime'] = df1['runtime'][i]
    directors['release_date'] = df1['release_date'][i]
    data1 = data1.append(directors)
#actors.append(df['actors'][1])
# data1.columns = ['time passed', 'gender']
data1 = data1.reset_index()
#data2 = data2.reset_index()
# data2
data1.rename(columns={'index': 'director', 0: 'days passed directors', 1: 'director_gender', 2: 'director_bday'}, inplace=True)
data1['days passed directors'] = data1['days passed directors'].apply(lambda x: abs(x[0]) if isinstance(x, list) else None)
data1['release_date'] = data1['release_date'].apply(lambda x: pd.to_datetime(x))
data1['director_bday'] = data1['director_bday'].apply(lambda x: pd.to_datetime(x))
data1['director_age'] = abs(data1['director_bday'] - data1['release_date'])
data1 = data1.drop('director_gender', 1)

# %%
data2 = pd.DataFrame()
for i in range(0, len(df1['actors'])):
    actors = pd.DataFrame(df1['actors'][i])
    actors=actors.T
    #actors['directors'] = df1['directors'][i]
    actors['title']=df1['title'][i]
    actors['Domestic'] = df1['domestic_total_gross'][i]
    actors['production'] = df1['production'][i]
    actors['runtime'] = df1['runtime'][i]
    actors['release_date'] = df1['release_date'][i]
    data2 = data2.append(actors)
data2 = data2.reset_index()
data2.rename(columns={'index': 'actor', 0: 'days passed actors', 1: 'actor_gender', 2: 'actor_bday'}, inplace=True)
data2['days passed actors'] = data2['days passed actors'].apply(lambda x: abs(x[0]) if isinstance(x, list) else None)
data2['release_date'] = data2['release_date'].apply(lambda x: pd.to_datetime(x))
data2['actor_bday'] = data2['actor_bday'].apply(lambda x: pd.to_datetime(x))
data2['actor_age'] = abs(data2['actor_bday'] - data2['release_date'])

# %%
bday = data2[data2['actor'] == 'M. Night Shyamalan']['actor_bday'].iloc[0]

# %%
release = data2[data2['actor'] == 'M. Night Shyamalan']['release_date'].iloc[0]

# %%
(bday-release).days/365.0
# Out:
# -30.317808219178083

# %%
data1.head(2)
# Out:
#           director  days passed directors director_bday  \
# 0       Ron Howard               812 days    1954-03-01
# 1  Robert Zemeckis              1062 days    1952-05-14
#
#                             title   Domestic  production  runtime  \
# 0  How the Grinch Stole Christmas  260044825   123000000      104
# 1                       Cast Away  233632142    90000000      143
#
#   release_date  director_age
# 0   2000-11-17    17063 days
# 1   2000-12-22    17754 days

# %%
data2.head(2)
# Out:
#              actor  days passed actors actor_gender actor_bday  \
# 0  Anthony Hopkins            140 days            0 1937-12-31
# 1       Jim Carrey            455 days            0 1962-01-17
#
#                             title   Domestic  production  runtime  \
# 0  How the Grinch Stole Christmas  260044825   123000000      104
# 1  How the Grinch Stole Christmas  260044825   123000000      104
#
#   release_date  actor_age
# 0   2000-11-17 22967 days
# 1   2000-11-17 14184 days

# %%
final = pd.merge(data1, data2, on = ['title','production', 'Domestic','runtime', 'release_date'])
final['ROI'] = final['Domestic']/final['production']
final
# Out:
#               director  days passed directors director_bday  \
# 0           Ron Howard               812 days    1954-03-01
# 1           Ron Howard               812 days    1954-03-01
# 2      Robert Zemeckis              1062 days    1952-05-14
# 3      Robert Zemeckis              1062 days    1952-05-14
# 4             John Woo              2155 days    1946-05-01
# 5             John Woo              2155 days    1946-05-01
# 6             John Woo              2155 days    1946-05-01
# 7             John Woo              2155 days    1946-05-01
# 8         Ridley Scott               294 days    1937-11-30
# 9         Ridley Scott               294 days    1937-11-30
# 10        Nancy Meyers              2100 days    1949-12-08
# 11        Nancy Meyers              2100 days    1949-12-08
# 12        Nancy Meyers              2100 days    1949-12-08
# 13        Nancy Meyers              2100 days    1949-12-08
# 14        Nancy Meyers              2100 days    1949-12-08
# 15        Nancy Meyers              2100 days    1949-12-08
# 16   Wolfgang Petersen               728 days    1941-03-14
# 17   Wolfgang Petersen               728 days    1941-03-14
# 18   Wolfgang Petersen               728 days    1941-03-14
# 19           Jay Roach              1183 days    1957-06-14
# 23             1        NaT        NaT  2.097330
# 24             1 1966-08-14 12388 days  2.097330
# 25             0 1968-10-12 11598 days  2.097330
# 26             0 1939-05-25 22331 days  2.097330
# 27             0 1973-09-18  9796 days  2.097330
# 28             0 1940-07-13 21916 days  2.097330
# 29             1 1972-11-06 10112 days  2.097330
# ..           ...        ...        ...       ...
# 772            0 1973-04-14 10847 days  0.930645
# 773         None 1948-03-14 19990 days  0.535510
# 774         None 1973-05-25 10787 days  0.535510
# 775            1 1963-07-30 14374 days  0.535510
# 776            0 1943-08-17 21661 days  0.535510
# 777            0 1980-11-12  7828 days  0.638915
# 778            1 1964-07-26 13781 days  0.638915
# 779            0 1962-04-02 14751 days  2.633094
# 780            0 1951-07-21 18659 days  2.633094
# 781            1 1948-06-28 19597 days  0.505390
# 782            0 1955-01-18 17202 days  0.505390
# 783            0 1937-12-31 23534 days  0.430859
# 784         None 1965-02-07 13634 days  0.430859
# 785            0 1962-08-13 14543 days  0.430859
# 786            0 1973-08-03 10535 days  0.430859
# 787            0 1973-03-08 10809 days  3.420486
# 788         None 1970-03-18 11895 days  3.420486
# 789            1 1971-09-19 11345 days  3.420486
# 790            0 1930-05-31 26368 days  0.524702
# 791            0 1953-05-24 18051 days  2.157083
# 792            0 1960-08-10 15416 days  2.157083
# 793            1 1968-04-19 12607 days  2.157083
# 794            0 1979-12-29  8336 days  2.157083
# 795            0 1969-08-18 12121 days  2.157083
# 796            0 1951-07-06 18739 days  2.157083
# 797         None        NaT        NaT  0.574841
# 798            1 1971-11-25 11096 days  0.574841
# 799            0 1969-01-14 12141 days  0.574841
# 800            1 1968-11-08 12208 days  0.574841
# 801            0 1969-02-22 12102 days  0.574841
#
# [802 rows x 15 columns]

# %%
len(data1)
# Out:
# 254

# %%
len(data2)
# Out:
# 1174

# %%
type(final['director_age'][0])
# Out:
# pandas.tslib.Timedelta

# %%
final['days passed directors'] = final['days passed directors'].apply(lambda day: abs((np.timedelta64(day) / np.timedelta64(1, 'D')) - 1).astype(int) if day else None)
final['days passed actors'] = final['days passed actors'].apply(lambda day: abs((np.timedelta64(day) / np.timedelta64(1, 'D')) - 1).astype(int) if day else None)
final['director_age'] = final['director_age'].apply(lambda age: abs(((np.timedelta64(age) / np.timedelta64(1, 'D')) - 1)/365).astype(int) if age else None)
final['actor_age'] = final['actor_age'].apply(lambda age: abs(((np.timedelta64(age) / np.timedelta64(1, 'D')) - 1)/365).astype(int) if age else None)
#abs((np.timedelta64(day) / np.timedelta64(1, 'D')) - 1).astype(int)

# %%
len(final)
# Out:
# 802

# %%
final = final[final['actor_age'] > 0]
final = final[final['director_age'] > 0]
final = final[final['days passed directors'] > 0]
final = final[final['days passed actors'] > 0]

# %%
type(final['actor_gender'][0])
# Out:
# str

# %%
male = final[final['actor_gender'] == 0.0]
female = final[final['actor_gender'] == 1.0]

# %%
final = final.dropna()
male = male.dropna()
female = female.dropna()

# %%
vals_to_replace = {0.0: 'Male', 1.0: 'Female'}
final['actor_gender'] = final['actor_gender'].map(vals_to_replace)
final
# Out:
# 16        Female 1965-01-22         35  1.304417
# 17          Male 1961-05-06         39  1.304417
# 18          Male 1971-06-05         29  1.304417
# 19          Male 1965-11-30         34  3.022619
# 20          Male 1968-11-18         31  3.022619
# 21          Male 1943-08-17         57  3.022619
# 22        Female 1982-07-24         17  2.097330
# 24        Female 1966-08-14         33  2.097330
# 25          Male 1968-10-12         31  2.097330
# 26          Male 1939-05-25         61  2.097330
# 27          Male 1973-09-18         26  2.097330
# 28          Male 1940-07-13         60  2.097330
# 29        Female 1972-11-06         27  2.097330
# 30        Female 1976-11-29         23  8.264198
# 31          Male 1958-06-08         42  8.264198
# ..           ...        ...        ...       ...
# 757         Male 1943-08-17         58  0.448032
# 760       Female 1964-02-05         37  1.117074
# 761         Male 1949-08-31         52  1.117074
# 762         Male 1942-07-13         60  0.351690
# 763         Male 1952-06-07         50  0.351690
# 764         Male 1971-03-07         31  0.351690
# 771         Male 1968-11-18         33  0.479445
# 772         Male 1973-04-14         29  0.930645
# 775       Female 1963-07-30         39  0.535510
# 776         Male 1943-08-17         59  0.535510
# 777         Male 1980-11-12         21  0.638915
# 778       Female 1964-07-26         37  0.638915
# 779         Male 1962-04-02         40  2.633094
# 780         Male 1951-07-21         51  2.633094
# 781       Female 1948-06-28         53  0.505390
# 782         Male 1955-01-18         47  0.505390
# 783         Male 1937-12-31         64  0.430859
# 785         Male 1962-08-13         39  0.430859
# 786         Male 1973-08-03         28  0.430859
# 790         Male 1930-05-31         72  0.524702
# 791         Male 1953-05-24         49  2.157083
# 792         Male 1960-08-10         42  2.157083
# 793       Female 1968-04-19         34  2.157083
# 794         Male 1979-12-29         22  2.157083
# 795         Male 1969-08-18         33  2.157083
# 796         Male 1951-07-06         51  2.157083
# 798       Female 1971-11-25         30  0.574841
# 799         Male 1969-01-14         33  0.574841
# 800       Female 1968-11-08         33  0.574841
# 801         Male 1969-02-22         33  0.574841
#
# [550 rows x 15 columns]

# %%
len(final)
# Out:
# 550

# %%
len(male)
# Out:
# 380

# %%
len(female)
# Out:
# 170

# %%
type(male['days passed actors'][0])
# Out:
# numpy.float64

# %% [markdown]
# ## Plots

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import gaussian_kde
import seaborn as sns

# %%
sns.jointplot(y = 'days passed actor', x = 'ROI', data = male, size = 8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1375-5df57a1a4443> in <module>()
# ----> 1 sns.jointplot(y = 'days passed actor', x = 'ROI', data = male, size = 8)
#
# /home/patrick/anaconda3/lib/python3.5/site-packages/seaborn/distributions.py in jointplot(x, y, data, kind, stat_func, color, size, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#     793     grid = JointGrid(x, y, data, dropna=dropna,
#     794                      size=size, ratio=ratio, space=space,
# --> 795                      xlim=xlim, ylim=ylim)
#     796
#     797     # Plot the data using the grid
#
# /home/patrick/anaconda3/lib/python3.5/site-packages/seaborn/axisgrid.py in __init__(self, x, y, data, size, ratio, space, dropna, xlim, ylim)
#    1638             not_na = pd.notnull(x) & pd.notnull(y)
#    1639             x = x[not_na]
# -> 1640             y = y[not_na]
#    1641
#    1642         # Find the names of the variables
#
# TypeError: string indices must be integers

# %%
sns.jointplot(y = 'actor_age', x = 'days passed directors', data = male, size = 8)

# %%
sns.jointplot(y = 'actor_age', x = 'days passed actors', data = final, size = 8)

# %%
sns.lmplot(y = 'Domestic', x = 'production', data = female, size = 8)

# %%
sns.lmplot(y = 'Domestic', x = 'production', data = final, size = 8, hue='actor_gender')

# %%
sns.jointplot(x = 'actor_age', y = 'ROI', data = final, size = 8)

# %%
# %matplotlib inline
sns.lmplot(y = 'Domestic', x = 'days passed directors', data = final, size=10, hue='actor_gender')

# %%
sns.pairplot(final, hue="actor_gender")

# %%
xs = np.linspace(0,2000,3200)
density_1 = gaussian_kde(df['days passed directors'].dropna())
density_1.covariance_factor = lambda : .25
density_1._compute_covariance()
plt.figure(figsize = (20,8))
plt.plot(xs,density_1(xs))
plt.fill(xs,density_1(xs),'b',alpha=0)
plt.xlabel('x',fontsize=30)    #add an x label
plt.ylabel('density of y',fontsize=30)    #add a y label
plt.text(np.mean(df['days passed actors'].dropna()),max(density_1(xs))/2.0,r'$\widehat{x}_1$',fontsize=30)

# %%
pal = dict(male="#6495ED", female="#F08080")
g = sns.lmplot( "days passed directors", "days passed actors",data = final, col = 'actor_gender', hue='actor_gender')

# %%
g = sns.jointplot( "days passed directors", "ROI", data=final, kind="reg",ylim=(0, 4), xlim=(0, 300), color="r", size=7)

# %%
sns.set(style="darkgrid")

# Make a custom palette with gendered colors
pal = dict(male="#6495ED", female="#F08080")

# Show the survival proability as a function of age and sex
g = sns.lmplot(x="actor_age", y="days passed directors",  hue="actor_gender", data=final, palette=pal, y_jitter=.02, logistic=True)
g.set(xlim=(0, 80), ylim=(-.05, 1.05))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1420-cbabb1a95277> in <module>()
#       5
#       6 # Show the survival proability as a function of age and sex
# ----> 7 g = sns.lmplot(x="actor_age", y="days passed directors",  hue="actor_gender", data=final, palette=pal, y_jitter=.02, logistic=True)
#       8 g.set(xlim=(0, 80), ylim=(-.05, 1.05))
#
# /home/patrick/anaconda3/lib/python3.5/site-packages/seaborn/linearmodels.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, size, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws)
#     541                        hue_order=hue_order, size=size, aspect=aspect,
#     542                        col_wrap=col_wrap, sharex=sharex, sharey=sharey,
# --> 543                        legend_out=legend_out)
#     544
#     545     # Add the markers here as FacetGrid has figured out how many levels of the
#
# /home/patrick/anaconda3/lib/python3.5/site-packages/seaborn/axisgrid.py in __init__(self, data, row, col, hue, col_wrap, sharex, sharey, size, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws)
#     233             hue_names = utils.categorical_order(data[hue], hue_order)
#     234
# --> 235         colors = self._get_palette(data, hue, hue_order, palette)
#     236
#     237         # Set up the lists of names for the row and column facet variables
#
# /home/patrick/anaconda3/lib/python3.5/site-packages/seaborn/axisgrid.py in _get_palette(self, data, hue, hue_order, palette)
#     155             # Allow for palette to map from hue variable names
#     156             elif isinstance(palette, dict):
# --> 157                 color_names = [palette[h] for h in hue_names]
#     158                 colors = color_palette(color_names, n_colors)
#     159
#
# /home/patrick/anaconda3/lib/python3.5/site-packages/seaborn/axisgrid.py in <listcomp>(.0)
#     155             # Allow for palette to map from hue variable names
#     156             elif isinstance(palette, dict):
# --> 157                 color_names = [palette[h] for h in hue_names]
#     158                 colors = color_palette(color_names, n_colors)
#     159
#
# KeyError: 'Male'

# %% [markdown]
# ## Models

# %%
g = sns.PairGrid(director,
                 x_vars=director.columns[-3:], y_vars= ['director'],
                 size=24, aspect=.25)

g.map(sns.stripplot, size=10, orient="h",
      palette="Reds_r", edgecolor="gray")


titles = ['Domestic']

for ax, title in zip(g.axes.flat, titles):

    # Set a different title for each axes
    ax.set(title=title)

    # Make the grid horizontal instead of vertical
    ax.xaxis.grid(False)
    ax.yaxis.grid(True)


sns.despine(left=True, bottom=True)

# %%
df.sort_values(by=['userid','price'],ascending=False).groupby('userid').head(1)

# %%
director = final.groupby('director').mean().sort_values(by=['actor_age'],ascending=False)
director = director.reset_index()
director = director[['director','actor_age','ROI','Domestic']]
director
# Out:
#                   director  actor_age        ROI      Domestic
# 0              Scott Hicks  63.000000   0.780186  2.418578e+07
# 1          Alexander Payne  59.500000   2.167210  6.501629e+07
# 2           Clint Eastwood  59.200000   1.218353  7.761883e+07
# 3          Nick Cassavetes  59.000000   1.993245  7.175680e+07
# 4             Renny Harlin  54.000000   0.348086  3.272006e+07
# 5                 Frank Oz  51.750000   1.045702  7.110771e+07
# 6               Tony Scott  51.000000   0.542283  6.236256e+07
# 7              Tom Shadyac  50.000000   0.505390  3.032340e+07
# 8          Michael Lembeck  49.000000   2.142097  1.392363e+08
# 9            Callie Khouri  48.333333   2.577741  6.959902e+07
# 10        William Friedkin  48.000000   1.022254  6.133523e+07
# 11        John Lee Hancock  48.000000   3.436367  7.560007e+07
# 12            Lee Tamahori  47.600000   1.153644  1.435693e+08
# 13               Rod Lurie  47.142857   0.619245  1.803187e+07
# 14         Kathryn Bigelow  47.000000   0.351690  3.516897e+07
# 15            Iain Softley  46.500000   0.740272  5.033848e+07
# 16             Woody Allen  46.400000   0.412938  1.141686e+07
# 17          Frank Darabont  45.666667   0.386212  2.780727e+07
# 18            Mark Romanek  45.500000   2.633094  3.159713e+07
# 19              Sam Mendes  45.400000   1.305685  1.044548e+08
# 20         Robert Zemeckis  45.250000   2.075278  1.945482e+08
# 21         Roger Donaldson  45.000000   0.432401  3.459209e+07
# 22             David Mamet  45.000000   0.602842  2.351084e+07
# 23         Martin Scorsese  44.600000   0.778120  7.781200e+07
# 24              Todd Field  44.500000  21.135649  3.593060e+07
# 25         Mark Pellington  44.500000   1.117074  3.574637e+07
# 26            Mike Nichols  44.333333   0.104860  6.291602e+06
# 27         Lasse Hallstrom  44.333333   1.438444  3.813428e+07
# 28              Peter Lord  44.000000   2.374101  1.068346e+08
# 29              Ron Howard  43.875000   2.736421  1.930680e+08
# ..                     ...        ...        ...           ...
# 109                 Tarsem  30.000000   1.858608  6.133406e+07
# 110           Dennis Dugan  30.000000   0.881910  1.940203e+07
# 111        Martin Campbell  30.000000   0.923251  6.924386e+07
# 112        Brian Helgeland  30.000000   0.870303  5.656970e+07
# 113              Don Bluth  29.666667   0.303379  2.275343e+07
# 114  Christopher McQuarrie  29.500000   0.712431  6.055661e+06
# 115         Robert Luketic  29.500000   5.362260  9.652067e+07
# 116         Gregory Hoblit  29.333333   1.451944  4.501028e+07
# 117            Jay Russell  29.250000   5.689107  3.413464e+07
# 118    Keenen Ivory Wayans  29.111111   5.295508  1.189261e+08
# 119       Barbet Schroeder  29.000000   0.638915  3.194575e+07
# 120          Brian Robbins  29.000000   1.256960  4.022273e+07
# 121         Robert Redford  29.000000   0.386490  3.091917e+07
# 122              Tim Story  29.000000   6.315175  7.578210e+07
# 123            David Twohy  29.000000   1.706116  3.924066e+07
# 124           Raja Gosnell  28.857143   2.722238  1.379793e+08
# 125              Sam Raimi  28.800000   2.904362  4.037064e+08
# 126     Paul W.S. Anderson  28.666667   1.215749  4.011971e+07
# 127       Courtney Solomon  28.000000   0.338237  1.522068e+07
# 128               Don Roos  28.000000   1.051580  3.680529e+07
# 129  Gina Prince-Bythewood  27.500000   1.372981  2.745962e+07
# 130          Sofia Coppola  27.400000   0.545137  4.906229e+06
# 131       Robert Rodriguez  26.750000   2.739830  9.928272e+07
# 132          Todd Phillips  26.000000   4.283799  6.854078e+07
# 133       Davis Guggenheim  24.333333   0.212867  5.108820e+06
# 134           Victor Salva  23.000000   3.790418  3.790418e+07
# 135             Boaz Yakin  23.000000   3.855158  1.156548e+08
# 136             Shawn Levy  21.666667   3.224036  4.836055e+07
# 137                Ang Lee  21.000000   7.534051  1.280789e+08
# 138            Peyton Reed  18.000000   2.442107  6.837900e+07
#
# [139 rows x 4 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.cross_validation import KFold, train_test_split, preprocessing
from patsy import dmatrices, dmatrix
import statsmodels.api as sm
from statsmodels.tools.eval_measures import mse
from sklearn.metrics import r2_score
from scipy.stats import linregress
from pylab import plot,show,hist

# %%
final.head(2)
# Out:
#      director  days passed directors director_bday  \
# 0  Ron Howard                    811    1954-03-01
# 1  Ron Howard                    811    1954-03-01
#
#                             title   Domestic  production  runtime  \
# 0  How the Grinch Stole Christmas  260044825   123000000      104
# 1  How the Grinch Stole Christmas  260044825   123000000      104
#
#   release_date  director_age            actor  days passed actors  \
# 0   2000-11-17            46  Anthony Hopkins                 139
# 1   2000-11-17            46       Jim Carrey                 454
#
#   actor_gender actor_bday  actor_age       ROI
# 0            0 1937-12-31         62  2.114186
# 1            0 1962-01-17         38  2.114186

# %%
data = final.ix[:, (1,4,5,6,8,10,13,14)]
len(data)
# Out:
# 550

# %%
data.head()
# Out:
#    days passed directors   Domestic  production  runtime  director_age  \
# 0                    811  260044825   123000000      104            46
# 1                    811  260044825   123000000      104            46
# 2                   1061  233632142    90000000      143            48
# 3                   1061  233632142    90000000      143            48
# 4                   2154  215409889   125000000      123            54
#
#    days passed actors  actor_age       ROI
# 0                 139         62  2.114186
# 1                 454         38  2.114186
# 2                 923         37  2.595913
# 3                 671         44  2.595913
# 4                 139         62  1.723279

# %%
len(DataNorm)
# Out:
# 688

# %%
y = data['ROI']
X = data.drop(['Domestic', 'production', 'ROI'], 1)
X['intercept']=1

# %%
y = data['Domestic']
X = data.drop(['Domestic','ROI', 'days passed actors', 'actor_age'], 1)
X['intercept']=1

# %%
X.head()
# Out:
#    days passed directors  production  runtime  director_age  intercept
# 0                    811   123000000      104            46          1
# 1                    811   123000000      104            46          1
# 2                   1061    90000000      143            48          1
# 3                   1061    90000000      143            48          1
# 4                   2154   125000000      123            54          1

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.25)

# %%
model = sm.OLS(y_train, X_train)
results = model.fit()

# %%
results = model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Domestic   R-squared:                       0.437
# Model:                            OLS   Adj. R-squared:                  0.431
# Method:                 Least Squares   F-statistic:                     78.86
# Date:                Thu, 21 Apr 2016   Prob (F-statistic):           1.74e-49
# Time:                        15:57:13   Log-Likelihood:                -7973.4
# No. Observations:                 412   AIC:                         1.596e+04
# Df Residuals:                     407   BIC:                         1.598e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------
# days passed directors -1.632e+04   5137.625     -3.177      0.002     -2.64e+04 -6221.845
# production                1.3297      0.100     13.242      0.000         1.132     1.527
# runtime                6.934e+05   1.59e+05      4.371      0.000      3.81e+05  1.01e+06
# director_age          -1.682e+06   2.79e+05     -6.018      0.000     -2.23e+06 -1.13e+06
# intercept              2.863e+07    2.1e+07      1.365      0.173     -1.26e+07  6.99e+07
# ==============================================================================
# Omnibus:                       35.880   Durbin-Watson:                   2.095
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.900
# Skew:                           0.778   Prob(JB):                     4.83e-10
# Kurtosis:                       3.280   Cond. No.                     4.77e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.77e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
y_predictTest = results.predict(X_test)

# %%
mse1  = mse(y_test, y_predictTest,  axis=0)
mse1
# Out:
# 3967430635847070.5

# %%
rSquared = r2_score(y_test, y_predictTest)
rSquared
# Out:
# 0.37962004645878422

# %%
rSqAdj = 1-(1-rSquared)*((len(y_test)-1)/(len(y_test)-len(X_test.columns))-1)
rSqAdj
# Out:
# 0.98134195628447474

# %%
len(data['production'])
# Out:
# 688

# %%
len(data['Domestic'])
# Out:
# 688

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LassoCV

# Load the dataset.
X, y = data['production'], data[]

# We use the base estimator LassoCV since the L1 norm promotes sparsity of features.
clf = LassoCV()

# Set a minimum threshold of 0.25
sfm = SelectFromModel(clf, threshold=0.25)
sfm.fit(X, y)
n_features = sfm.transform(X).shape[1]

# Reset the threshold till the number of features equals two.
# Note that the attribute can be set directly instead of repeatedly
# fitting the metatransformer.
while n_features > 2:
    sfm.threshold += 0.1
    X_transform = sfm.transform(X)
    n_features = X_transform.shape[1]

# Plot the selected two features from X.
plt.title(
    "Features selected from movie data using SelectFromModel with "
    "threshold %0.3f." % sfm.threshold)
feature1 = X_transform[:, 0]
feature2 = X_transform[:, 1] 
plt.plot(feature1, feature2, 'r.')
plt.xlabel("Feature number 1")
plt.ylabel("Feature number 2")
plt.ylim([np.min(feature2), np.max(feature2)])
plt.show()
# Out:
# /home/patrick/anaconda3/lib/python3.5/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-808-6b8bc19ee03e> in <module>()
#      10 # Set a minimum threshold of 0.25
#      11 sfm = SelectFromModel(clf, threshold=0.25)
# ---> 12 sfm.fit(X, y)
#      13 n_features = sfm.transform(X).shape[1]
#      14
#
# /home/patrick/anaconda3/lib/python3.5/site-packages/sklearn/feature_selection/from_model.py in fit(self, X, y, **fit_params)
#     228         if not hasattr(self, "estimator_"):
#     229             self.estimator_ = clone(self.estimator)
# --> 230         self.estimator_.fit(X, y, **fit_params)
#     231         return self
#     232
#
# /home/patrick/anaconda3/lib/python3.5/site-packages/sklearn/linear_model/coordinate_descent.py in fit(self, X, y)
#    1093         if X.shape[0] != y.shape[0]:
#    1094             raise ValueError("X and y have inconsistent dimensions (%d != %d)"
# -> 1095                              % (X.shape[0], y.shape[0]))
#    1096
#    1097         # All LinearModelCV parameters except 'cv' are acceptable
#
# ValueError: X and y have inconsistent dimensions (1 != 688)
